# %%
import requests
from requests.auth import HTTPBasicAuth
import urllib3

# 경고 끄기
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

# 기본 설정
url = 'https://corners.synology.me:30006/woojin-dev490/ProcCat/447477ef-0986-4d2a-80f5-69d445b8a803'
username = 'csdtpcp'       # 아이디
password = 'dtpcp!@'       # 비밀번호

# 요청 보내기
response = requests.get(url, auth=HTTPBasicAuth(username, password), verify=False)

# 응답 확인
if response.status_code == 200:
    data = response.json()  # JSON 형식으로 파싱
    print(data)
    # # JSON 파일로 저장
    # import json
    # with open('output.json', 'w', encoding='utf-8') as f:
    #     json.dump(data, f, ensure_ascii=False, indent=4)
else:
    print(f'접근 실패: 상태 코드 {response.status_code}')
# Out:
# {'code': 0, 'message': 'SUCCESS', 'data': [{'pcId': 'ee9d0398-8fae-48e4-b1a8-dbdc4029b4da', 'upPcId': None, 'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803', 'pcLevel': 1, 'pcSeq': 1, 'pcNm': '차체', 'pcCd': 'PROC0001', 'desc1': '차체 대분류'}, {'pcId': 'd74ea2d0-477c-4834-a610-172e766cc33a', 'upPcId': None, 'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803', 'pcLevel': 1, 'pcSeq': 2, 'pcNm': '차체 운송', 'pcCd': 'PROC0020', 'desc1': '차체 운송 대분류'}, {'pcId': 'e39ff221-f1d2-48b7-901a-4e3f279fbcef', 'upPcId': None, 'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803', 'pcLevel': 1, 'pcSeq': 5000, 'pcNm': '도장', 'pcCd': 'PROC0002', 'desc1': '도장'}, {'pcId': '6916e757-6569-4fad-ad78-569c90e016ea', 'upPcId': None, 'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803', 'pcLevel': 1, 'pcSeq': 5001, 'pcNm': '도장 운송', 'pcCd': 'PROC0020', 'desc1': '도장운송 대분류'}, {'pcId': '43dc4be4-2330-4e3a-8fef-84ec188a094a', 'upPcId': None, 'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803', 'pcLevel': 1, 'pcSeq': 10000, 'pcNm': '선행의장', 'pcCd': 'PROC0003', 'desc1': '선행 의장'}, {'pcId': '4be70c30-e383-48e7-b8e1-1e8de4357089', 'upPcId': None, 'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803', 'pcLevel': 1, 'pcSeq': 10001, 'pcNm': '선행의장 운송', 'pcCd': 'PROC0020', 'desc1': '선행의장 운송'}, {'pcId': '4c8af4fe-454e-4884-8327-9623e9923a0b', 'upPcId': None, 'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803', 'pcLevel': 1, 'pcSeq': 15000, 'pcNm': '의장/전장/기장', 'pcCd': 'PROC0004', 'desc1': '본의장'}, {'pcId': 'dde13271-cc37-4d59-8795-d3e958c7e3b2', 'upPcId': None, 'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803', 'pcLevel': 1, 'pcSeq': 15001, 'pcNm': '본의장 운송', 'pcCd': 'PROC0020', 'desc1': '본의장 운송'}, {'pcId': 'a6d4515d-4c91-4676-934e-9d20e705cc38', 'upPcId': None, 'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803', 'pcLevel': 1, 'pcSeq': 20000, 'pcNm': '대차 차입', 'pcCd': 'PROC0005', 'desc1': '대차'}, {'pcId': 'a9547daf-e330-4478-9326-da0f865e68cd', 'upPcId': None, 'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803', 'pcLevel': 1, 'pcSeq': 20001, 'pcNm': '대차 운송', 'pcCd': 'PROC0020', 'desc1': '대차 운송'}, {'pcId': 'c95df008-e3f6-4d55-9325-8e76da5fc734', 'upPcId': 'ee9d0398-8fae-48e4-b1a8-dbdc4029b4da', 'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803', 'pcLevel': 2, 'pcSeq': 100, 'pcNm': 'UNDER PANEL 조립 & 검사 & 자동용접', 'pcCd': 'PROC0001', 'desc1': '차체01'}, {'pcId': 'd8cae93e-2ffb-4671-bd01-0428fafac15c', 'upPcId': 'd74ea2d0-477c-4834-a610-172e766cc33a', 'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803', 'pcLevel': 2, 'pcSeq': 300, 'pcNm': '운송 차제2->차체3', 'pcCd': 'PROC0020', 'desc1': '차체 운송'}, {'pcId': 'f699b89c-1a78-4619-89d3-c4e61dfc1123', 'upPcId': 'ee9d0398-8fae-48e4-b1a8-dbdc4029b4da', 'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803', 'pcLevel': 2, 'pcSeq': 400, 'pcNm': 'UNDER PANEL 교정', 'pcCd': 'PROC0001', 'desc1': '차체03'}, {'pcId': '6bc11d3e-0474-496c-8695-bb7a10a6b963', 'upPcId': 'd74ea2d0-477c-4834-a610-172e766cc33a', 'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803', 'pcLevel': 2, 'pcSeq': 500, 'pcNm': '운송 차제3->차체4', 'pcCd': 'PROC0020', 'desc1': '차체 운송'}, {'pcId': '8fd9915f-40b7-40f6-9c5f-b8b09dc0637b', 'upPcId': 'ee9d0398-8fae-48e4-b1a8-dbdc4029b4da', 'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803', 'pcLevel': 2, 'pcSeq': 600, 'pcNm': 'UNDER PANEL 가공', 'pcCd': 'PROC0001', 'desc1': '차체04'}, {'pcId': 'fb60f1fe-b34f-42cd-b826-0b08a66f7605', 'upPcId': 'd74ea2d0-477c-4834-a610-172e766cc33a', 'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803', 'pcLevel': 2, 'pcSeq': 700, 'pcNm': '운송 차제4->차체5', 'pcCd': 'PROC0020', 'desc1': '차체 운송'}, {'pcId': '918cc8fa-2e23-4f8f-be97-058385110bd6', 'upPcId': 'ee9d0398-8fae-48e4-b1a8-dbdc4029b4da', 'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803', 'pcLevel': 2, 'pcSeq': 800, 'pcNm': 'UNDER PANEL 세척/사상/검사', 'pcCd': 'PROC0001', 'desc1': '차체05'}, {'pcId': 'eceb61bd-a848-4eaf-8b64-fc48e70b0da7', 'upPcId': 'd74ea2d0-477c-4834-a610-172e766cc33a', 'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803', 'pcLevel': 2, 'pcSeq': 900, 'pcNm': '운송 차제5->차체6', 'pcCd': 'PROC0020', 'desc1': '차체 운송'}, {'pcId': '75dbd44 ...
