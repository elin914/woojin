# %%
import requests
from requests.auth import HTTPBasicAuth
import urllib3
import json
import pandas as pd

# 경고 끄기
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

def load_api(url, save_data=False):  
    # 기본 설정
    username = 'csdtpcp'       # 아이디
    password = 'dtpcp!@'       # 비밀번호
    # 요청 보내기
    response = requests.get(url, auth=HTTPBasicAuth(username, password), verify=False)

    # 응답 확인
    if response.status_code == 200:
        data = response.json()  # JSON 형식으로 파싱
        if save_data:
            # JSON 파일로 저장
            with open('output.json', 'w', encoding='utf-8') as f:
                json.dump(data, f, ensure_ascii=False, indent=4)
    else:
        print(f'접근 실패: 상태 코드 {response.status_code}')
        return False       
    return data

# %%
url_process_category = 'https://corners.synology.me:30006/woojin-dev490/ProcCat/447477ef-0986-4d2a-80f5-69d445b8a803'
data_process_category = load_api(url_process_category)

# %%
data_process_category
# Out:
# {'code': 0,
#  'message': 'SUCCESS',
#  'data': [{'pcId': 'ee9d0398-8fae-48e4-b1a8-dbdc4029b4da',
#    'upPcId': None,
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 1,
#    'pcSeq': 1,
#    'pcNm': '차체',
#    'pcCd': 'PROC0001',
#    'desc1': '차체 대분류'},
#   {'pcId': 'd74ea2d0-477c-4834-a610-172e766cc33a',
#    'upPcId': None,
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 1,
#    'pcSeq': 2,
#    'pcNm': '차체 운송',
#    'pcCd': 'PROC0020',
#    'desc1': '차체 운송 대분류'},
#   {'pcId': 'e39ff221-f1d2-48b7-901a-4e3f279fbcef',
#    'upPcId': None,
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 1,
#    'pcSeq': 5000,
#    'pcNm': '도장',
#    'pcCd': 'PROC0002',
#    'desc1': '도장'},
#   {'pcId': '6916e757-6569-4fad-ad78-569c90e016ea',
#    'upPcId': None,
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 1,
#    'pcSeq': 5001,
#    'pcNm': '도장 운송',
#    'pcCd': 'PROC0020',
#    'desc1': '도장운송 대분류'},
#   {'pcId': '43dc4be4-2330-4e3a-8fef-84ec188a094a',
#    'upPcId': None,
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 1,
#    'pcSeq': 10000,
#    'pcNm': '선행의장',
#    'pcCd': 'PROC0003',
#    'desc1': '선행 의장'},
#   {'pcId': '4be70c30-e383-48e7-b8e1-1e8de4357089',
#    'upPcId': None,
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 1,
#    'pcSeq': 10001,
#    'pcNm': '선행의장 운송',
#    'pcCd': 'PROC0020',
#    'desc1': '선행의장 운송'},
#   {'pcId': '4c8af4fe-454e-4884-8327-9623e9923a0b',
#    'upPcId': None,
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 1,
#    'pcSeq': 15000,
#    'pcNm': '의장/전장/기장',
#    'pcCd': 'PROC0004',
#    'desc1': '본의장'},
#   {'pcId': 'dde13271-cc37-4d59-8795-d3e958c7e3b2',
#    'upPcId': None,
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 1,
#    'pcSeq': 15001,
#    'pcNm': '본의장 운송',
#    'pcCd': 'PROC0020',
#    'desc1': '본의장 운송'},
#   {'pcId': 'a6d4515d-4c91-4676-934e-9d20e705cc38',
#    'upPcId': None,
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 1,
#    'pcSeq': 20000,
#    'pcNm': '대차 차입',
#    'pcCd': 'PROC0005',
#    'desc1': '대차'},
#   {'pcId': 'a9547daf-e330-4478-9326-da0f865e68cd',
#    'upPcId': None,
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 1,
#    'pcSeq': 20001,
#    'pcNm': '대차 운송',
#    'pcCd': 'PROC0020',
#    'desc1': '대차 운송'},
#   {'pcId': 'c95df008-e3f6-4d55-9325-8e76da5fc734',
#    'upPcId': 'ee9d0398-8fae-48e4-b1a8-dbdc4029b4da',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 100,
#    'pcNm': 'UNDER PANEL 조립 & 검사 & 자동용접',
#    'pcCd': 'PROC0001',
#    'desc1': '차체01'},
#   {'pcId': 'd8cae93e-2ffb-4671-bd01-0428fafac15c',
#    'upPcId': 'd74ea2d0-477c-4834-a610-172e766cc33a',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 300,
#    'pcNm': '운송 차제2->차체3',
#    'pcCd': 'PROC0020',
#    'desc1': '차체 운송'},
#   {'pcId': 'f699b89c-1a78-4619-89d3-c4e61dfc1123',
#    'upPcId': 'ee9d0398-8fae-48e4-b1a8-dbdc4029b4da',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 400,
#    'pcNm': 'UNDER PANEL 교정',
#    'pcCd': 'PROC0001',
#    'desc1': '차체03'},
#   {'pcId': '6bc11d3e-0474-496c-8695-bb7a10a6b963',
#    'upPcId': 'd74ea2d0-477c-4834-a610-172e766cc33a',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 500,
#    'pcNm': '운송 차제3->차체4',
#    'pcCd': 'PROC0020',
#    'desc1': '차체 운송'},
#   {'pcId': '8fd9915f-40b7-40f6-9c5f-b8b09dc0637b',
#    'upPcId': 'ee9d0398-8fae-48e4-b1a8-dbdc4029b4da',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 600,
#    'pcNm': 'UNDER PANEL 가공',
#    'pcCd': 'PROC0001',
#    'desc1': '차체04'},
#   {'pcId': 'fb60f1fe-b34f-42cd-b826-0b08a66f7605',
#    'upPcId': 'd74ea2d0-477c-4834-a610-172e766cc33a',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 700,
#    'pcNm': '운송 차제4->차체5',
#    'pcCd': 'PROC0020',
#    'desc1': '차체 운송'},
#   {'pcId': '918cc8fa-2e23-4f8f-be97-058385110bd6',
#    'upPcId': 'ee9d0398-8fae-48e4-b1a8-dbdc4029b4da',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 800,
#    'pcNm': 'UNDER PANEL 세척/사상/검사',
#    'pcCd': 'PROC0001',
#    'desc1': '차체05'},
#   {'pcId': 'eceb61bd-a848-4eaf-8b64-fc48e70b0da7',
#    'upPcId': 'd74ea2d0-477c-4834-a610-172e766cc33a',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 900,
#    'pcNm': '운송 차제5->차체6',
#    'pcCd': 'PROC0020',
#    'desc1': '차체 운송'},
#   {'pcId': '75dbd449-84cb-4b01-912c-9534a82dba86',
#    'upPcId': 'ee9d0398-8fae-48e4-b1a8-dbdc4029b4da',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 1000,
#    'pcNm': 'UNDER SIDE SILL 조립 & 자동용접',
#    'pcCd': 'PROC0001',
#    'desc1': '차체06'},
#   {'pcId': '1a2e285b-19a2-4737-84ba-d9ab6c6c0569',
#    'upPcId': 'd74ea2d0-477c-4834-a610-172e766cc33a',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 1010,
#    'pcNm': '운송 차제6->차체7',
#    'pcCd': 'PROC0020',
#    'desc1': '차체 운송'},
#   {'pcId': '63a45548-9e55-4d82-87c1-58c341b56d92',
#    'upPcId': 'ee9d0398-8fae-48e4-b1a8-dbdc4029b4da',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 1100,
#    'pcNm': 'UNDER SIDE SILL 교정',
#    'pcCd': 'PROC0001',
#    'desc1': '차체07'},
#   {'pcId': '94e88d72-7547-4b5e-8800-2e46a011c1da',
#    'upPcId': 'd74ea2d0-477c-4834-a610-172e766cc33a',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 1200,
#    'pcNm': '운송 차제7->차체8',
#    'pcCd': 'PROC0020',
#    'desc1': '차체 운송'},
#   {'pcId': '87cfd948-e4c6-4fe9-ad7b-7efb6cf50dab',
#    'upPcId': 'ee9d0398-8fae-48e4-b1a8-dbdc4029b4da',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 1300,
#    'pcNm': 'UNDER PANEL 팽창폼 삽입',
#    'pcCd': 'PROC0001',
#    'desc1': '차체08'},
#   {'pcId': 'e23d9718-0747-4584-8dd0-4cfdddac2df0',
#    'upPcId': 'd74ea2d0-477c-4834-a610-172e766cc33a',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 1400,
#    'pcNm': '운송 차제8->차체9',
#    'pcCd': 'PROC0020',
#    'desc1': '차체 운송'},
#   {'pcId': '1882b1f4-8d1c-473f-83fc-8919bddd3352',
#    'upPcId': 'ee9d0398-8fae-48e4-b1a8-dbdc4029b4da',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 1500,
#    'pcNm': 'UNDER FRAME ASSY END SILL 용접',
#    'pcCd': 'PROC0001',
#    'desc1': '차체09'},
#   {'pcId': '862d5173-dad1-4525-a291-7940b376af33',
#    'upPcId': 'd74ea2d0-477c-4834-a610-172e766cc33a',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 1600,
#    'pcNm': '운송 차제9->차체10',
#    'pcCd': 'PROC0020',
#    'desc1': '차체 운송'},
#   {'pcId': '1440901b-592e-48e2-81f9-9b1dbf47811e',
#    'upPcId': 'ee9d0398-8fae-48e4-b1a8-dbdc4029b4da',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 1700,
#    'pcNm': 'UNDER FRAME ASSY 2차 조립 & 용접 & 검사',
#    'pcCd': 'PROC0001',
#    'desc1': '차체10'},
#   {'pcId': 'b10ec2e5-d611-4066-84a5-184adf8352cf',
#    'upPcId': 'd74ea2d0-477c-4834-a610-172e766cc33a',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 1800,
#    'pcNm': '운송 차제10->차체11',
#    'pcCd': 'PROC0020',
#    'desc1': '차체 운송'},
#   {'pcId': '0dafa58f-2a4e-4384-996a-cc7f6108e4d5',
#    'upPcId': 'ee9d0398-8fae-48e4-b1a8-dbdc4029b4da',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 1900,
#    'pcNm': 'UNDER FRAME 2차 가공',
#    'pcCd': 'PROC0001',
#    'desc1': '차체11'},
#   {'pcId': '8bd21d79-0608-4fbd-9732-c026b160a0d3',
#    'upPcId': 'd74ea2d0-477c-4834-a610-172e766cc33a',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 2000,
#    'pcNm': '운송 차제11->차체12',
#    'pcCd': 'PROC0020',
#    'desc1': '차체 운송'},
#   {'pcId': '127b4116-5f15-40bd-82f2-b8e1338318ae',
#    'upPcId': 'ee9d0398-8fae-48e4-b1a8-dbdc4029b4da',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 2100,
#    'pcNm': 'UNDER FRAME 가공 세척/사상 & 용접',
#    'pcCd': 'PROC0001',
#    'desc1': '차체12'},
#   {'pcId': '97b12327-083f-4618-9d1f-7290f8a173d4',
#    'upPcId': 'd74ea2d0-477c-4834-a610-172e766cc33a',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 2200,
#    'pcNm': '운송 차제12->차체13',
#    'pcCd': 'PROC0020',
#    'desc1': '차체 운송'},
#   {'pcId': 'efc892ae-5100-4a67-ba33-99786200b666',
#    'upPcId': 'ee9d0398-8fae-48e4-b1a8-dbdc4029b4da',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 2300,
#    'pcNm': 'UNDER FRAME ASSY 검사',
#    'pcCd': 'PROC0001',
#    'desc1': '차체13'},
#   {'pcId': 'a21c867b-f627-4d9b-850b-8630d7dd0a27',
#    'upPcId': 'd74ea2d0-477c-4834-a610-172e766cc33a',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 2400,
#    'pcNm': '운송 차제13->차체14',
#    'pcCd': 'PROC0020',
#    'desc1': '차체 운송'},
#   {'pcId': 'f5032bdb-3465-42d1-828e-dc8aa2980c06',
#    'upPcId': 'ee9d0398-8fae-48e4-b1a8-dbdc4029b4da',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 2500,
#    'pcNm': 'UNDER/END/SIDE/ROOF 조립',
#    'pcCd': 'PROC0001',
#    'desc1': '차체14'},
#   {'pcId': '642cb792-5960-4eca-ad3c-a3f6fc95fe73',
#    'upPcId': 'd74ea2d0-477c-4834-a610-172e766cc33a',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 2600,
#    'pcNm': '운송 차제14->차체15',
#    'pcCd': 'PROC0020',
#    'desc1': '차체 운송'},
#   {'pcId': '5b3571ee-7808-4279-85ea-997e193f1c48',
#    'upPcId': 'ee9d0398-8fae-48e4-b1a8-dbdc4029b4da',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 2700,
#    'pcNm': 'CARBODY 자동 & 수동용접',
#    'pcCd': 'PROC0001',
#    'desc1': '차체15'},
#   {'pcId': 'ba2281fd-f8d8-4e99-8b2b-b975c8e350a2',
#    'upPcId': 'd74ea2d0-477c-4834-a610-172e766cc33a',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 2800,
#    'pcNm': '운송 차제15->차체16',
#    'pcCd': 'PROC0020',
#    'desc1': '차체 운송'},
#   {'pcId': 'f846708b-272d-42f8-b4e6-450ff383b544',
#    'upPcId': 'ee9d0398-8fae-48e4-b1a8-dbdc4029b4da',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 2900,
#    'pcNm': 'CARBODY ASSY 용접 & 교정 & 사상 & 검사',
#    'pcCd': 'PROC0001',
#    'desc1': '차체16'},
#   {'pcId': '988aebf5-1d5b-4b92-ae2f-33d585e5e4e3',
#    'upPcId': 'd74ea2d0-477c-4834-a610-172e766cc33a',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 3000,
#    'pcNm': '운송 차제16->차체17',
#    'pcCd': 'PROC0020',
#    'desc1': '차체 운송'},
#   {'pcId': 'c924aa02-4e54-4f15-adfd-ebcdba5dc3eb',
#    'upPcId': 'ee9d0398-8fae-48e4-b1a8-dbdc4029b4da',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 3100,
#    'pcNm': 'CARBODY ASSY 교정 & 수정 & 완성검사',
#    'pcCd': 'PROC0001',
#    'desc1': '차체17'},
#   {'pcId': '751f014a-97fc-4e92-bfdf-4477ef4e60fd',
#    'upPcId': 'd74ea2d0-477c-4834-a610-172e766cc33a',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 3200,
#    'pcNm': '운송 차체->도장',
#    'pcCd': 'PROC0020',
#    'desc1': '차체 운송'},
#   {'pcId': '5ee1d7d7-f0f5-4921-8ebd-3487d0aafbca',
#    'upPcId': 'e39ff221-f1d2-48b7-901a-4e3f279fbcef',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 5100,
#    'pcNm': 'SHOT 작업',
#    'pcCd': 'PROC0002',
#    'desc1': '도장01'},
#   {'pcId': '429012f3-c02f-4306-aef6-44115d84a06d',
#    'upPcId': 'e39ff221-f1d2-48b7-901a-4e3f279fbcef',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 5105,
#    'pcNm': 'SHOT작업 및 전처리검사',
#    'pcCd': 'PROC0002',
#    'desc1': '도장01'},
#   {'pcId': 'f22abfd3-2677-4d30-a677-b1c29cd44fd3',
#    'upPcId': 'e39ff221-f1d2-48b7-901a-4e3f279fbcef',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 5200,
#    'pcNm': '전처리검사',
#    'pcCd': 'PROC0002',
#    'desc1': '도장02'},
#   {'pcId': '0cd0a204-5d31-48e0-99c0-82c753980f5f',
#    'upPcId': '6916e757-6569-4fad-ad78-569c90e016ea',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 5300,
#    'pcNm': '운송 도장2->도장3',
#    'pcCd': 'PROC0020',
#    'desc1': '도장운송'},
#   {'pcId': 'f3df35f8-f770-4a01-96a1-e780dd793329',
#    'upPcId': 'e39ff221-f1d2-48b7-901a-4e3f279fbcef',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 5400,
#    'pcNm': '하도 및 건조',
#    'pcCd': 'PROC0002',
#    'desc1': '도장03'},
#   {'pcId': 'a8660b9d-6343-480d-a553-c963a5484bbc',
#    'upPcId': '6916e757-6569-4fad-ad78-569c90e016ea',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 5500,
#    'pcNm': '운송 도장3->도장4',
#    'pcCd': 'PROC0020',
#    'desc1': '도장운송'},
#   {'pcId': '6353fb65-dbd8-4dec-b685-eab314f61d08',
#    'upPcId': 'e39ff221-f1d2-48b7-901a-4e3f279fbcef',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 5600,
#    'pcNm': '용접수정 및 검사',
#    'pcCd': 'PROC0002',
#    'desc1': '도장04'},
#   {'pcId': '9990cad1-b0f2-4920-a200-63e868401bd2',
#    'upPcId': '6916e757-6569-4fad-ad78-569c90e016ea',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 5700,
#    'pcNm': '운송 도장4->도장5',
#    'pcCd': 'PROC0020',
#    'desc1': '도장운송'},
#   {'pcId': '59f84876-1421-4095-b6b2-847f8f07cff3',
#    'upPcId': 'e39ff221-f1d2-48b7-901a-4e3f279fbcef',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 5800,
#    'pcNm': '하도수정 및 검사',
#    'pcCd': 'PROC0002',
#    'desc1': '도장05,도장06'},
#   {'pcId': '8bc2cea2-2982-44f5-986c-9f55f4ad7c13',
#    'upPcId': '6916e757-6569-4fad-ad78-569c90e016ea',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 5900,
#    'pcNm': '운송 도장5->도장6',
#    'pcCd': 'PROC0020',
#    'desc1': '도장운송'},
#   {'pcId': '7a5d245b-413e-4ede-ad86-52dbdb887d74',
#    'upPcId': 'e39ff221-f1d2-48b7-901a-4e3f279fbcef',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 6000,
#    'pcNm': '퍼티 1차',
#    'pcCd': 'PROC0002',
#    'desc1': '도장07'},
#   {'pcId': '4ae243ea-abc7-4b15-ba98-7cc43060e044',
#    'upPcId': 'e39ff221-f1d2-48b7-901a-4e3f279fbcef',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 6005,
#    'pcNm': '퍼티 및 퍼티 검사',
#    'pcCd': 'PROC0002',
#    'desc1': '도장07'},
#   {'pcId': '53124e53-b5f7-440f-9981-c65c437ea77a',
#    'upPcId': 'e39ff221-f1d2-48b7-901a-4e3f279fbcef',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 6100,
#    'pcNm': '퍼티 2차',
#    'pcCd': 'PROC0002',
#    'desc1': '도장07'},
#   {'pcId': 'a8d0b04b-89b3-4f0f-8036-d8ad86127674',
#    'upPcId': 'e39ff221-f1d2-48b7-901a-4e3f279fbcef',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 6200,
#    'pcNm': '퍼티 3차',
#    'pcCd': 'PROC0002',
#    'desc1': '도장07'},
#   {'pcId': 'a9223416-7ce9-4e76-8323-c7ecac1a4dec',
#    'upPcId': 'e39ff221-f1d2-48b7-901a-4e3f279fbcef',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 6300,
#    'pcNm': '퍼티 4차',
#    'pcCd': 'PROC0002',
#    'desc1': '도장07'},
#   {'pcId': '4183436e-4ce1-4a8e-b087-a31473227307',
#    'upPcId': 'e39ff221-f1d2-48b7-901a-4e3f279fbcef',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 6400,
#    'pcNm': '퍼티 연마',
#    'pcCd': 'PROC0002',
#    'desc1': '도장07'},
#   {'pcId': '08070a70-9091-4aaf-ba2c-a2003d3180ca',
#    'upPcId': 'e39ff221-f1d2-48b7-901a-4e3f279fbcef',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 6500,
#    'pcNm': '퍼티검사',
#    'pcCd': 'PROC0002',
#    'desc1': '도장07'},
#   {'pcId': 'ccac7bbd-36e3-46ce-9a4d-32b1928314b2',
#    'upPcId': '6916e757-6569-4fad-ad78-569c90e016ea',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 6600,
#    'pcNm': '운송 도장6->도장7',
#    'pcCd': 'PROC0020',
#    'desc1': '도장운송'},
#   {'pcId': '4844b8f1-69b4-466f-acb0-29c4d34e5191',
#    'upPcId': 'e39ff221-f1d2-48b7-901a-4e3f279fbcef',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 6700,
#    'pcNm': '중도 (중도 + 중도 touch up)',
#    'pcCd': 'PROC0002',
#    'desc1': '도장08'},
#   {'pcId': '26af1e48-b74c-46af-b3cb-76a5f8ea39f9',
#    'upPcId': 'e39ff221-f1d2-48b7-901a-4e3f279fbcef',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 6705,
#    'pcNm': '중도 및 중도검사',
#    'pcCd': 'PROC0002',
#    'desc1': '도장08'},
#   {'pcId': '4d4e0f1b-6fe1-4e16-aad0-e75f5f2b88e0',
#    'upPcId': 'e39ff221-f1d2-48b7-901a-4e3f279fbcef',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 6800,
#    'pcNm': '중도검사',
#    'pcCd': 'PROC0002',
#    'desc1': '도장08'},
#   {'pcId': '497f8480-67f9-493d-8fde-06f8b5327f44',
#    'upPcId': '6916e757-6569-4fad-ad78-569c90e016ea',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 6900,
#    'pcNm': '운송 도장7->도장8',
#    'pcCd': 'PROC0020',
#    'desc1': '도장운송'},
#   {'pcId': 'e7d43022-9aad-4377-bf77-308ac4eb2a60',
#    'upPcId': 'e39ff221-f1d2-48b7-901a-4e3f279fbcef',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 7000,
#    'pcNm': '상도',
#    'pcCd': 'PROC0002',
#    'desc1': '도장10'},
#   {'pcId': '5c7b28a1-3e17-4b0b-854a-70b87aa03c07',
#    'upPcId': 'e39ff221-f1d2-48b7-901a-4e3f279fbcef',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 7005,
#    'pcNm': '상도 및 상도검사',
#    'pcCd': 'PROC0002',
#    'desc1': '도장10'},
#   {'pcId': '6beb19b7-2d40-4ad0-aacb-a6b14c0920bf',
#    'upPcId': 'e39ff221-f1d2-48b7-901a-4e3f279fbcef',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 7100,
#    'pcNm': '상도검사',
#    'pcCd': 'PROC0002',
#    'desc1': '도장11'},
#   {'pcId': '12cabe47-10f9-4cc2-bce9-ca0d69e4e37a',
#    'upPcId': '6916e757-6569-4fad-ad78-569c90e016ea',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 7200,
#    'pcNm': '운송 도장8->도장9',
#    'pcCd': 'PROC0020',
#    'desc1': '도장운송'},
#   {'pcId': '04b9a556-44c0-4e4b-bb0d-9063174d7a06',
#    'upPcId': 'e39ff221-f1d2-48b7-901a-4e3f279fbcef',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 7300,
#    'pcNm': '안티슬립 하도 방음도장',
#    'pcCd': 'PROC0002',
#    'desc1': '도장12'},
#   {'pcId': '6a3df80e-38d6-4b0f-8b67-66109ddc7eb5',
#    'upPcId': 'e39ff221-f1d2-48b7-901a-4e3f279fbcef',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 7305,
#    'pcNm': '안티슬립 및 상도/방음검사',
#    'pcCd': 'PROC0002',
#    'desc1': '도장12'},
#   {'pcId': 'f492c160-94f8-4bd7-948d-8bbc28a1f2cc',
#    'upPcId': 'e39ff221-f1d2-48b7-901a-4e3f279fbcef',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 7400,
#    'pcNm': '지붕도막재 하도 검사',
#    'pcCd': 'PROC0002',
#    'desc1': '도장12'},
#   {'pcId': '38859cd1-66f2-4191-af7e-dec93f495070',
#    'upPcId': 'e39ff221-f1d2-48b7-901a-4e3f279fbcef',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 7500,
#    'pcNm': '안티슬립 중도 방음도장',
#    'pcCd': 'PROC0002',
#    'desc1': '도장12'},
#   {'pcId': '1e6129b1-841c-46eb-a86d-4c29a70e45f7',
#    'upPcId': 'e39ff221-f1d2-48b7-901a-4e3f279fbcef',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 7600,
#    'pcNm': '지붕도막재 중도 검사',
#    'pcCd': 'PROC0002',
#    'desc1': '도장12'},
#   {'pcId': '2be67cc4-3d54-4765-8896-3ca05e3ae440',
#    'upPcId': 'e39ff221-f1d2-48b7-901a-4e3f279fbcef',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 7700,
#    'pcNm': '안티슬립 규사, 상도 방음도장',
#    'pcCd': 'PROC0002',
#    'desc1': '도장12'},
#   {'pcId': 'de30a8a4-79c9-4e34-85fe-60023c29cecd',
#    'upPcId': 'e39ff221-f1d2-48b7-901a-4e3f279fbcef',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 7800,
#    'pcNm': '전체가수 및 씰링',
#    'pcCd': 'PROC0002',
#    'desc1': '도장12'},
#   {'pcId': '9f04e9d9-f137-4ae4-a1aa-2b2156fc4d90',
#    'upPcId': 'e39ff221-f1d2-48b7-901a-4e3f279fbcef',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 7900,
#    'pcNm': '지붕도막재 규사, 상도/방음 도장 검사',
#    'pcCd': 'PROC0002',
#    'desc1': '도장12'},
#   {'pcId': '34aa983f-d526-4304-9a9f-5c4465a59ae5',
#    'upPcId': '6916e757-6569-4fad-ad78-569c90e016ea',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 8000,
#    'pcNm': '운송 도장->선행의장',
#    'pcCd': 'PROC0020',
#    'desc1': '도장운송'},
#   {'pcId': '5b98b9da-3f06-4c40-af9d-2b59e8b69553',
#    'upPcId': '43dc4be4-2330-4e3a-8fef-84ec188a094a',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 10010,
#    'pcNm': '선행 의장',
#    'pcCd': 'PROC0003',
#    'desc1': '선행 의장 작업'},
#   {'pcId': 'fd1d46cd-645f-4e0e-85bf-20d79ecfb7de',
#    'upPcId': '43dc4be4-2330-4e3a-8fef-84ec188a094a',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 10100,
#    'pcNm': '평활재시공 & 단열재 취부',
#    'pcCd': 'PROC0003',
#    'desc1': '선행 의장01'},
#   {'pcId': 'ef359edf-4fff-4f8b-9684-f42aa03c8867',
#    'upPcId': '43dc4be4-2330-4e3a-8fef-84ec188a094a',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 10200,
#    'pcNm': '단열재 취부 검사',
#    'pcCd': 'PROC0003',
#    'desc1': '선행 의장01'},
#   {'pcId': 'b91bf6ab-ca3f-4d8a-be79-835104a201aa',
#    'upPcId': '43dc4be4-2330-4e3a-8fef-84ec188a094a',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 10300,
#    'pcNm': '평활재 연마',
#    'pcCd': 'PROC0003',
#    'desc1': '선행 의장01'},
#   {'pcId': 'bfd1df3f-442c-4e2a-af86-a900932183b1',
#    'upPcId': '43dc4be4-2330-4e3a-8fef-84ec188a094a',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 10400,
#    'pcNm': '평활재 시공상태 검사',
#    'pcCd': 'PROC0003',
#    'desc1': '선행 의장01'},
#   {'pcId': '90ca1b63-e619-4317-a7ef-600380035d19',
#    'upPcId': '43dc4be4-2330-4e3a-8fef-84ec188a094a',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 10500,
#    'pcNm': '바닥재 시공',
#    'pcCd': 'PROC0003',
#    'desc1': '선행 의장01'},
#   {'pcId': 'a7fdcda6-e65d-4d7d-a560-9181674da457',
#    'upPcId': '43dc4be4-2330-4e3a-8fef-84ec188a094a',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 10600,
#    'pcNm': '바닥재 시공상태 검사',
#    'pcCd': 'PROC0003',
#    'desc1': '선행 의장01'},
#   {'pcId': '4a40aedc-4f24-4556-aea0-4cede93d75db',
#    'upPcId': '4be70c30-e383-48e7-b8e1-1e8de4357089',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 10601,
#    'pcNm': '운송 선행의장 -> 의장',
#    'pcCd': 'PROC0020',
#    'desc1': '선행의장 운송'},
#   {'pcId': 'fca679fe-ecfd-4d7a-824d-86a7b525a747',
#    'upPcId': '4c8af4fe-454e-4884-8327-9623e9923a0b',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 15010,
#    'pcNm': '의장/전장/기장',
#    'pcCd': 'PROC0004',
#    'desc1': '본의장 작업'},
#   {'pcId': '9bcd0605-b0f7-4c0d-a0db-9afdd18dbaa5',
#    'upPcId': '4c8af4fe-454e-4884-8327-9623e9923a0b',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 15100,
#    'pcNm': '보호합판 시공',
#    'pcCd': 'PROC0004',
#    'desc1': '의장정지점01'},
#   {'pcId': '04d93668-d017-4e12-9b68-91e5f8659123',
#    'upPcId': '4c8af4fe-454e-4884-8327-9623e9923a0b',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 15200,
#    'pcNm': '흡음재 취부 검사',
#    'pcCd': 'PROC0004',
#    'desc1': '의장정지점01'},
#   {'pcId': '9b39e181-10d9-414c-a26e-951318b5788b',
#    'upPcId': '4c8af4fe-454e-4884-8327-9623e9923a0b',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 15300,
#    'pcNm': '실내배선',
#    'pcCd': 'PROC0004',
#    'desc1': '의장정지점02'},
#   {'pcId': '15e3dd3e-f906-43e7-8b92-51cea1041575',
#    'upPcId': '4c8af4fe-454e-4884-8327-9623e9923a0b',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 15400,
#    'pcNm': '리무벌 프레임 취부',
#    'pcCd': 'PROC0004',
#    'desc1': '의장정지점02'},
#   {'pcId': '20a49b75-027a-4d92-ad2b-9e6c6951e55f',
#    'upPcId': '4c8af4fe-454e-4884-8327-9623e9923a0b',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 15500,
#    'pcNm': '측창취부',
#    'pcCd': 'PROC0004',
#    'desc1': '의장정지점02'},
#   {'pcId': '35c45949-df55-47fe-9e85-e3d072c04f82',
#    'upPcId': '4c8af4fe-454e-4884-8327-9623e9923a0b',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 15600,
#    'pcNm': '실내 입선 검사',
#    'pcCd': 'PROC0004',
#    'desc1': '의장정지점02'},
#   {'pcId': 'e501e6ac-440a-4986-a224-de994d591cda',
#    'upPcId': '4c8af4fe-454e-4884-8327-9623e9923a0b',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 15700,
#    'pcNm': 'AIR DUCT MODULE 취부',
#    'pcCd': 'PROC0004',
#    'desc1': '의장정지점03'},
#   {'pcId': '3e57d1b0-89e2-4fde-80ac-7ed42fd0368b',
#    'upPcId': '4c8af4fe-454e-4884-8327-9623e9923a0b',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 15800,
#    'pcNm': '덕트류 취부검사',
#    'pcCd': 'PROC0004',
#    'desc1': '의장정지점03'},
#   {'pcId': '17bc3eec-e56a-4a59-8d23-3a569cdf0678',
#    'upPcId': '4c8af4fe-454e-4884-8327-9623e9923a0b',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 15900,
#    'pcNm': 'AIR DUCT MODULE 취부 & 상하 CABLE HARNESS 배선',
#    'pcCd': 'PROC0004',
#    'desc1': '의장정지점04'},
#   {'pcId': '9a576bf8-269f-4e10-be99-715362923096',
#    'upPcId': '4c8af4fe-454e-4884-8327-9623e9923a0b',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 16000,
#    'pcNm': '상하 입선검사',
#    'pcCd': 'PROC0004',
#    'desc1': '의장정지점04'},
#   {'pcId': 'd8f6fd55-00a6-445d-87e5-94ed725375aa',
#    'upPcId': '4c8af4fe-454e-4884-8327-9623e9923a0b',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 16100,
#    'pcNm': '객실도어 & 배전반 & 상하 전선관',
#    'pcCd': 'PROC0004',
#    'desc1': '의장정지점05'},
#   {'pcId': '66633651-3b19-451c-8803-75f7031c40f8',
#    'upPcId': '4c8af4fe-454e-4884-8327-9623e9923a0b',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 16200,
#    'pcNm': '제동배관 취부검사',
#    'pcCd': 'PROC0004',
#    'desc1': '의장정지점05'},
#   {'pcId': 'c55f0a27-4c46-4088-90c6-8dd49dfd8cf0',
#    'upPcId': '4c8af4fe-454e-4884-8327-9623e9923a0b',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 16300,
#    'pcNm': '객실 도어 & 측정 & 배관 & 공기관 취부 & 누기시험',
#    'pcCd': 'PROC0004',
#    'desc1': '의장정지점06'},
#   {'pcId': 'b40ef8a6-f7b5-47b6-884b-b2d49890f755',
#    'upPcId': '4c8af4fe-454e-4884-8327-9623e9923a0b',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 16400,
#    'pcNm': '제동기기 취부 및 누설검사',
#    'pcCd': 'PROC0004',
#    'desc1': '의장정지점06'},
#   {'pcId': 'f856b18f-4e89-4e40-b59a-44451a718696',
#    'upPcId': '4c8af4fe-454e-4884-8327-9623e9923a0b',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 16500,
#    'pcNm': '내장판 & 배전반 & DOOR & 전선관 배관',
#    'pcCd': 'PROC0004',
#    'desc1': '의장정지점07'},
#   {'pcId': '0b7e0872-cd00-431e-a855-e04a90033416',
#    'upPcId': '4c8af4fe-454e-4884-8327-9623e9923a0b',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 16600,
#    'pcNm': '냉방장치 & 공기관 배관',
#    'pcCd': 'PROC0004',
#    'desc1': '의장정지점07'},
#   {'pcId': '5f9b130c-0215-42ab-bd15-98163c8f557b',
#    'upPcId': '4c8af4fe-454e-4884-8327-9623e9923a0b',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 16700,
#    'pcNm': '내장판 & 옥상 & 형광등',
#    'pcCd': 'PROC0004',
#    'desc1': '의장정지점07'},
#   {'pcId': 'f84cdf28-7a76-4aa7-a6c4-20816df13be8',
#    'upPcId': '4c8af4fe-454e-4884-8327-9623e9923a0b',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 16800,
#    'pcNm': 'cover & 형광등 & 전광판& LJB 취부 및 결선',
#    'pcCd': 'PROC0004',
#    'desc1': '의장정지점07'},
#   {'pcId': '98346133-4396-46b8-9562-91e4ddc96ce7',
#    'upPcId': '4c8af4fe-454e-4884-8327-9623e9923a0b',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 16900,
#    'pcNm': 'SIDE DOOR & HINGE &FAN & 등구류 & 제동기기결선 및 취부',
#    'pcCd': 'PROC0004',
#    'desc1': '의장정지점07'},
#   {'pcId': '4f2e8e92-8933-4108-94ca-d3e9a5711db3',
#    'upPcId': '4c8af4fe-454e-4884-8327-9623e9923a0b',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 17000,
#    'pcNm': 'DOOR/END & 전장품 &옥상 전장기기 취부',
#    'pcCd': 'PROC0004',
#    'desc1': '의장정지점07'},
#   {'pcId': 'f94c0dff-2fa7-43a2-9579-e194f3d3554e',
#    'upPcId': '4c8af4fe-454e-4884-8327-9623e9923a0b',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 17100,
#    'pcNm': '내장판 취부 검사',
#    'pcCd': 'PROC0004',
#    'desc1': '의장정지점07'},
#   {'pcId': '4461b19b-0b71-44c2-8474-93e669d113ba',
#    'upPcId': '4c8af4fe-454e-4884-8327-9623e9923a0b',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 17200,
#    'pcNm': '소형기기 취부 결선',
#    'pcCd': 'PROC0004',
#    'desc1': '의장정지점08'},
#   {'pcId': 'e51e83d7-c708-4f70-98c4-2e742165234b',
#    'upPcId': '4c8af4fe-454e-4884-8327-9623e9923a0b',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 17300,
#    'pcNm': '상하 전장기기 결선',
#    'pcCd': 'PROC0004',
#    'desc1': '의장정지점08'},
#   {'pcId': '70572a6d-3939-4553-ab8d-74b86a9905cf',
#    'upPcId': '4c8af4fe-454e-4884-8327-9623e9923a0b',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 17400,
#    'pcNm': '선반 & 전장 & 상하부품 취부',
#    'pcCd': 'PROC0004',
#    'desc1': '의장정지점08'},
#   {'pcId': '94a8a3d1-3ebe-4a10-8b02-457583dc11fb',
#    'upPcId': '4c8af4fe-454e-4884-8327-9623e9923a0b',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 17500,
#    'pcNm': 'TRACTION MOTOR 결선 (1차)& COUPLER 취부',
#    'pcCd': 'PROC0004',
#    'desc1': '의장정지점08'},
#   {'pcId': '075d7819-4fcd-49f8-9dec-9dd612be9b64',
#    'upPcId': '4c8af4fe-454e-4884-8327-9623e9923a0b',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 17600,
#    'pcNm': '점검카바 취부',
#    'pcCd': 'PROC0004',
#    'desc1': '의장정지점08'},
#   {'pcId': 'e673c4e1-e9fa-48e9-be49-56581f1007e5',
#    'upPcId': '4c8af4fe-454e-4884-8327-9623e9923a0b',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 17700,
#    'pcNm': 'TRACTION MOTOR 결선 (2차)',
#    'pcCd': 'PROC0004',
#    'desc1': '의장정지점08'},
#   {'pcId': '2e3ec9bc-8030-44f1-b85b-6b38927e04f4',
#    'upPcId': '4c8af4fe-454e-4884-8327-9623e9923a0b',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 17800,
#    'pcNm': '실내명판 & 옥상기기 취부',
#    'pcCd': 'PROC0004',
#    'desc1': '의장정지점08'},
#   {'pcId': '48206028-be0a-4da1-bfae-321267fb7e49',
#    'upPcId': '4c8af4fe-454e-4884-8327-9623e9923a0b',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 17900,
#    'pcNm': '하부 M/D & 실외 전장품 취부 및 결선',
#    'pcCd': 'PROC0004',
#    'desc1': '의장정지점08'},
#   {'pcId': '26ac3069-9063-41c6-815e-5e5f45e15b6f',
#    'upPcId': '4c8af4fe-454e-4884-8327-9623e9923a0b',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 18000,
#    'pcNm': '실외설비품 & 소화기 취부',
#    'pcCd': 'PROC0004',
#    'desc1': '의장정지점08'},
#   {'pcId': '9edc7ea7-e9c9-4e2d-91c8-a0f69f9a3b40',
#    'upPcId': '4c8af4fe-454e-4884-8327-9623e9923a0b',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 18100,
#    'pcNm': '실내설비/전장품 취부검사',
#    'pcCd': 'PROC0004',
#    'desc1': '의장정지점08'},
#   {'pcId': '5e4eb94d-7980-4dee-81a8-f06fe847bc73',
#    'upPcId': 'dde13271-cc37-4d59-8795-d3e958c7e3b2',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 18101,
#    'pcNm': '운송 본의장 -> 완성 의장',
#    'pcCd': 'PROC0020',
#    'desc1': '본의장 운송'},
#   {'pcId': '64af7702-2d7a-44c1-8325-ca25acc93516',
#    'upPcId': 'a6d4515d-4c91-4676-934e-9d20e705cc38',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 20100,
#    'pcNm': '대차 차입 및 배관 마무리작업',
#    'pcCd': 'PROC0005',
#    'desc1': '대차'},
#   {'pcId': '1e2fea59-e4f1-4a18-a452-7b33a7066992',
#    'upPcId': 'a9547daf-e330-4478-9326-da0f865e68cd',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 2,
#    'pcSeq': 20301,
#    'pcNm': '운송 의장 -> 완료검사',
#    'pcCd': 'PROC0020',
#    'desc1': '대차 운송'},
#   {'pcId': 'df11c13b-c0e5-4752-b631-bd2e64b1f70a',
#    'upPcId': '5b98b9da-3f06-4c40-af9d-2b59e8b69553',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 3,
#    'pcSeq': 10101,
#    'pcNm': '파이프 프레임, 탭시트',
#    'pcCd': 'PROC0003',
#    'desc1': None},
#   {'pcId': '16e3f252-1292-4c73-b607-ed7f3984f57a',
#    'upPcId': '5b98b9da-3f06-4c40-af9d-2b59e8b69553',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 3,
#    'pcSeq': 10102,
#    'pcNm': '방풍라바,와이어스포트',
#    'pcCd': 'PROC0003',
#    'desc1': None},
#   {'pcId': 'd7b258b0-7d5c-4399-a921-eb887972a623',
#    'upPcId': '5b98b9da-3f06-4c40-af9d-2b59e8b69553',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 3,
#    'pcSeq': 10103,
#    'pcNm': '이너프레임',
#    'pcCd': 'PROC0003',
#    'desc1': None},
#   {'pcId': '18281c11-0f94-4624-87d3-0cf7d038740b',
#    'upPcId': '5b98b9da-3f06-4c40-af9d-2b59e8b69553',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 3,
#    'pcSeq': 10104,
#    'pcNm': '단열재 취부',
#    'pcCd': 'PROC0003',
#    'desc1': None},
#   {'pcId': '0b8da7ae-d903-44cf-9f41-976bab95f418',
#    'upPcId': '5b98b9da-3f06-4c40-af9d-2b59e8b69553',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 3,
#    'pcSeq': 10201,
#    'pcNm': '단열재 검사',
#    'pcCd': 'PROC0003',
#    'desc1': None},
#   {'pcId': '548c019f-35e1-494a-bd76-48d0cbd07626',
#    'upPcId': '5b98b9da-3f06-4c40-af9d-2b59e8b69553',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 3,
#    'pcSeq': 10301,
#    'pcNm': '평활재 건조',
#    'pcCd': 'PROC0003',
#    'desc1': None},
#   {'pcId': '498ee22c-29db-45f0-ae49-f73c2b78309b',
#    'upPcId': '5b98b9da-3f06-4c40-af9d-2b59e8b69553',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 3,
#    'pcSeq': 10401,
#    'pcNm': '평활재 검사',
#    'pcCd': 'PROC0003',
#    'desc1': None},
#   {'pcId': '14ca0941-e5ef-4966-8955-4c0c6135f026',
#    'upPcId': '5b98b9da-3f06-4c40-af9d-2b59e8b69553',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 3,
#    'pcSeq': 10501,
#    'pcNm': '바닥재 건조',
#    'pcCd': 'PROC0003',
#    'desc1': None},
#   {'pcId': '62871c1d-ecdb-47ca-b4b8-e6cd7e15e72e',
#    'upPcId': '5b98b9da-3f06-4c40-af9d-2b59e8b69553',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 3,
#    'pcSeq': 10601,
#    'pcNm': '바닥재 검사',
#    'pcCd': 'PROC0003',
#    'desc1': None},
#   {'pcId': '8718b46d-cf23-4b2f-959c-c1a63f9532b6',
#    'upPcId': 'fca679fe-ecfd-4d7a-824d-86a7b525a747',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 3,
#    'pcSeq': 15201,
#    'pcNm': '흡음재 취부',
#    'pcCd': 'PROC0004',
#    'desc1': None},
#   {'pcId': 'c30eb0bd-a767-409a-a968-75aa0757bfb0',
#    'upPcId': 'fca679fe-ecfd-4d7a-824d-86a7b525a747',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 3,
#    'pcSeq': 15202,
#    'pcNm': '흡음재 씰링/검사/수정',
#    'pcCd': 'PROC0004',
#    'desc1': None},
#   {'pcId': '9684b295-a3a7-4568-a740-9abedef89f1d',
#    'upPcId': 'fca679fe-ecfd-4d7a-824d-86a7b525a747',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 3,
#    'pcSeq': 15203,
#    'pcNm': 'T-BOLT 취부',
#    'pcCd': 'PROC0004',
#    'desc1': None},
#   {'pcId': '4582b8b3-4158-474f-afc4-bc44fe69414d',
#    'upPcId': 'fca679fe-ecfd-4d7a-824d-86a7b525a747',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 3,
#    'pcSeq': 15305,
#    'pcNm': '배기팬 커버 취부',
#    'pcCd': 'PROC0004',
#    'desc1': None},
#   {'pcId': 'c4e7bbaf-1f0d-463d-a58a-2e2f113fc634',
#    'upPcId': 'fca679fe-ecfd-4d7a-824d-86a7b525a747',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 3,
#    'pcSeq': 15306,
#    'pcNm': '전장품 취부 및 고압 배선 압착작업',
#    'pcCd': 'PROC0004',
#    'desc1': None},
#   {'pcId': '5f00c772-1919-4f2e-b207-7800abfebf66',
#    'upPcId': 'fca679fe-ecfd-4d7a-824d-86a7b525a747',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 3,
#    'pcSeq': 15308,
#    'pcNm': '내전압 검사 (상,하 전기)',
#    'pcCd': 'PROC0004',
#    'desc1': None},
#   {'pcId': 'dfaa3623-fb92-499b-b2af-971057321edf',
#    'upPcId': 'fca679fe-ecfd-4d7a-824d-86a7b525a747',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 3,
#    'pcSeq': 15502,
#    'pcNm': '실내 배선',
#    'pcCd': 'PROC0004',
#    'desc1': None},
#   {'pcId': '3c54d4fe-0cee-4882-9696-56d698171860',
#    'upPcId': 'fca679fe-ecfd-4d7a-824d-86a7b525a747',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 3,
#    'pcSeq': 15503,
#    'pcNm': '실내 입선 검사',
#    'pcCd': 'PROC0004',
#    'desc1': None},
#   {'pcId': '2750ae8b-4dd4-4caa-951a-e7aeb373ed43',
#    'upPcId': 'fca679fe-ecfd-4d7a-824d-86a7b525a747',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 3,
#    'pcSeq': 15505,
#    'pcNm': '일반 배전반 취부',
#    'pcCd': 'PROC0004',
#    'desc1': None},
#   {'pcId': '406bf879-8f51-45d1-b524-3f6564e40421',
#    'upPcId': 'fca679fe-ecfd-4d7a-824d-86a7b525a747',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 3,
#    'pcSeq': 15508,
#    'pcNm': '냉난방 배전반 배선 및 컨넥트 작업',
#    'pcCd': 'PROC0004',
#    'desc1': None},
#   {'pcId': 'a8c2efbe-8d05-4c91-bff2-f13ce16e0be3',
#    'upPcId': 'fca679fe-ecfd-4d7a-824d-86a7b525a747',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 3,
#    'pcSeq': 15509,
#    'pcNm': '운전실 1차 배선 작업',
#    'pcCd': 'PROC0004',
#    'desc1': None},
#   {'pcId': 'c501f7c9-8258-4202-82c8-95df07c58d71',
#    'upPcId': 'fca679fe-ecfd-4d7a-824d-86a7b525a747',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 3,
#    'pcSeq': 15513,
#    'pcNm': '운전실 2차 배선작업 및 기기류 컨넥트 작업',
#    'pcCd': 'PROC0004',
#    'desc1': None},
#   {'pcId': 'f3b9bd9d-eba6-4fa5-98fb-3202fe0b5f1b',
#    'upPcId': 'fca679fe-ecfd-4d7a-824d-86a7b525a747',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 3,
#    'pcSeq': 15595,
#    'pcNm': '실내/상하 CABLE HARNESS 취부',
#    'pcCd': 'PROC0004',
#    'desc1': None},
#   {'pcId': '803d1d3c-6efd-4a42-bfbf-cccb4868bbfd',
#    'upPcId': 'fca679fe-ecfd-4d7a-824d-86a7b525a747',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 3,
#    'pcSeq': 15596,
#    'pcNm': '실내/상하 배선',
#    'pcCd': 'PROC0004',
#    'desc1': None},
#   {'pcId': 'e0471187-5ee5-4fed-8383-c102704e26df',
#    'upPcId': 'fca679fe-ecfd-4d7a-824d-86a7b525a747',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 3,
#    'pcSeq': 15597,
#    'pcNm': 'D+1~4일차 조정작업',
#    'pcCd': 'PROC0004',
#    'desc1': None},
#   {'pcId': '0c210f4c-8d06-4d56-b0ee-e5f5c2fc3727',
#    'upPcId': 'fca679fe-ecfd-4d7a-824d-86a7b525a747',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 3,
#    'pcSeq': 15597,
#    'pcNm': '실내/상하 입선 검사/수정',
#    'pcCd': 'PROC0004',
#    'desc1': None},
#   {'pcId': '51eab8d3-38d2-453b-962e-6f16e0ffa081',
#    'upPcId': 'fca679fe-ecfd-4d7a-824d-86a7b525a747',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 3,
#    'pcSeq': 15598,
#    'pcNm': '리무벌프레임 취부',
#    'pcCd': 'PROC0004',
#    'desc1': None},
#   {'pcId': 'b1d76e32-b363-49ed-9d1e-df5fe4699ed1',
#    'upPcId': 'fca679fe-ecfd-4d7a-824d-86a7b525a747',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 3,
#    'pcSeq': 15599,
#    'pcNm': 'AIR DUCT MODULE 취부',
#    'pcCd': 'PROC0004',
#    'desc1': None},
#   {'pcId': '93d2cc2b-a71f-40c0-ae8d-0d2af8885f9c',
#    'upPcId': 'fca679fe-ecfd-4d7a-824d-86a7b525a747',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 3,
#    'pcSeq': 15600,
#    'pcNm': '측창취부',
#    'pcCd': 'PROC0004',
#    'desc1': None},
#   {'pcId': '612897d8-78df-4b88-bcc0-b4e1d942a1c2',
#    'upPcId': 'fca679fe-ecfd-4d7a-824d-86a7b525a747',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 3,
#    'pcSeq': 15601,
#    'pcNm': 'STOP PLATE & 센터그릴 취부',
#    'pcCd': 'PROC0004',
#    'desc1': None},
#   {'pcId': '748b10f6-6a7d-4594-b68b-341d5340f56e',
#    'upPcId': 'fca679fe-ecfd-4d7a-824d-86a7b525a747',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 3,
#    'pcSeq': 15602,
#    'pcNm': '파티션 프레임 취부',
#    'pcCd': 'PROC0004',
#    'desc1': None},
#   {'pcId': '3f69f52d-c206-43a5-abd1-d47eb8e8aabf',
#    'upPcId': 'fca679fe-ecfd-4d7a-824d-86a7b525a747',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 3,
#    'pcSeq': 15602,
#    'pcNm': 'LINE FLOW FAN 취부 결선',
#    'pcCd': 'PROC0004',
#    'desc1': None},
#   {'pcId': 'f1441ccb-398b-46fd-b9e8-128c5fa49bb2',
#    'upPcId': 'fca679fe-ecfd-4d7a-824d-86a7b525a747',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 3,
#    'pcSeq': 15603,
#    'pcNm': 'AIR DUCT MODULE 취부 검사',
#    'pcCd': 'PROC0004',
#    'desc1': None},
#   {'pcId': '04dbb438-9874-4cb3-ba23-48dba6b6aab7',
#    'upPcId': 'fca679fe-ecfd-4d7a-824d-86a7b525a747',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 3,
#    'pcSeq': 15604,
#    'pcNm': 'CAB MODULE 취부',
#    'pcCd': 'PROC0004',
#    'desc1': None},
#   {'pcId': '19eade95-30e7-41f4-ba1f-e09e09614c4a',
#    'upPcId': 'fca679fe-ecfd-4d7a-824d-86a7b525a747',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 3,
#    'pcSeq': 15605,
#    'pcNm': 'AIR CON 취부',
#    'pcCd': 'PROC0004',
#    'desc1': None},
#   {'pcId': '239fddf2-c250-4761-a14f-2a941a9fda75',
#    'upPcId': 'fca679fe-ecfd-4d7a-824d-86a7b525a747',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 3,
#    'pcSeq': 15606,
#    'pcNm': 'ROOF 내장판 취부',
#    'pcCd': 'PROC0004',
#    'desc1': None},
#   {'pcId': 'fdb5af99-eac4-4ece-9f42-0c6639fdce5c',
#    'upPcId': 'fca679fe-ecfd-4d7a-824d-86a7b525a747',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 3,
#    'pcSeq': 15607,
#    'pcNm': '운전실 내장판/캐비넷 취부',
#    'pcCd': 'PROC0004',
#    'desc1': None},
#   {'pcId': '7dac19ab-a4d8-431f-95a9-199e3dbaa684',
#    'upPcId': 'fca679fe-ecfd-4d7a-824d-86a7b525a747',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 3,
#    'pcSeq': 15608,
#    'pcNm': '배관 MODULE 취부',
#    'pcCd': 'PROC0004',
#    'desc1': None},
#   {'pcId': '6b0dcc6c-9fea-42c5-947c-6815ba40370b',
#    'upPcId': 'fca679fe-ecfd-4d7a-824d-86a7b525a747',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 3,
#    'pcSeq': 15608,
#    'pcNm': '객실 도어 취부',
#    'pcCd': 'PROC0004',
#    'desc1': None},
#   {'pcId': 'ec8c85a2-43d9-45b7-ae01-5bfba1cdd28e',
#    'upPcId': 'fca679fe-ecfd-4d7a-824d-86a7b525a747',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 3,
#    'pcSeq': 15608,
#    'pcNm': '일반,냉난방 배전반 취부 결선',
#    'pcCd': 'PROC0004',
#    'desc1': None},
#   {'pcId': '2f14336a-38e5-4650-ab56-b8045fac5be0',
#    'upPcId': 'fca679fe-ecfd-4d7a-824d-86a7b525a747',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 3,
#    'pcSeq': 15609,
#    'pcNm': '옥상기기 취부 결선',
#    'pcCd': 'PROC0004',
#    'desc1': None},
#   {'pcId': 'ffe4e06d-cc13-472c-9bbf-7aceb852c0af',
#    'upPcId': 'fca679fe-ecfd-4d7a-824d-86a7b525a747',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 3,
#    'pcSeq': 15610,
#    'pcNm': '상하 전장기기 취부 결선',
#    'pcCd': 'PROC0004',
#    'desc1': None},
#   {'pcId': '27f617fd-d1b3-4175-bb84-f24c848d3090',
#    'upPcId': 'fca679fe-ecfd-4d7a-824d-86a7b525a747',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 3,
#    'pcSeq': 15611,
#    'pcNm': 'CENTER PIVOT 취부',
#    'pcCd': 'PROC0004',
#    'desc1': None},
#   {'pcId': '3d3a7a3e-2326-40e5-b810-e98df91b745d',
#    'upPcId': 'fca679fe-ecfd-4d7a-824d-86a7b525a747',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 3,
#    'pcSeq': 15611,
#    'pcNm': '도통 검사',
#    'pcCd': 'PROC0004',
#    'desc1': None},
#   {'pcId': '127fdb1e-97fd-4525-a4c2-05dd123dff8b',
#    'upPcId': 'fca679fe-ecfd-4d7a-824d-86a7b525a747',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 3,
#    'pcSeq': 15612,
#    'pcNm': '부적합수정',
#    'pcCd': 'PROC0004',
#    'desc1': None},
#   {'pcId': 'fce31937-b674-4400-8ceb-776864a641ed',
#    'upPcId': 'fca679fe-ecfd-4d7a-824d-86a7b525a747',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 3,
#    'pcSeq': 15612,
#    'pcNm': 'COUPLER 취부',
#    'pcCd': 'PROC0004',
#    'desc1': None},
#   {'pcId': '9184fc1e-f9f5-4dd6-b2f5-e942b9613b27',
#    'upPcId': 'fca679fe-ecfd-4d7a-824d-86a7b525a747',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 3,
#    'pcSeq': 15613,
#    'pcNm': '도통입회검사/내전압자체검사',
#    'pcCd': 'PROC0004',
#    'desc1': None},
#   {'pcId': 'aa77dbb8-fa64-403f-9e40-f4a1b398b7bf',
#    'upPcId': 'fca679fe-ecfd-4d7a-824d-86a7b525a747',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 3,
#    'pcSeq': 15613,
#    'pcNm': '제동기기 취부 및 누설검사',
#    'pcCd': 'PROC0004',
#    'desc1': None},
#   {'pcId': 'afcd8387-dc68-4d2e-8068-d1e01e619e89',
#    'upPcId': 'fca679fe-ecfd-4d7a-824d-86a7b525a747',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 3,
#    'pcSeq': 15614,
#    'pcNm': 'SIDE 내장판 취부',
#    'pcCd': 'PROC0004',
#    'desc1': None},
#   {'pcId': '95b44996-4c78-4d27-808c-8c457ce76be8',
#    'upPcId': 'fca679fe-ecfd-4d7a-824d-86a7b525a747',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 3,
#    'pcSeq': 15614,
#    'pcNm': '내전압 입회검사',
#    'pcCd': 'PROC0004',
#    'desc1': None},
#   {'pcId': '552d31ba-12f7-4fc3-b9e9-19610c5b64fc',
#    'upPcId': 'fca679fe-ecfd-4d7a-824d-86a7b525a747',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 3,
#    'pcSeq': 15615,
#    'pcNm': '코너씰링',
#    'pcCd': 'PROC0004',
#    'desc1': None},
#   {'pcId': '30238e8d-aa85-40d0-b621-578ed1d9bd00',
#    'upPcId': 'fca679fe-ecfd-4d7a-824d-86a7b525a747',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 3,
#    'pcSeq': 15615,
#    'pcNm': 'D+5~16일차 조정작업',
#    'pcCd': 'PROC0004',
#    'desc1': None},
#   {'pcId': '002cfaa5-4bf1-4325-9d54-281b9e4f439e',
#    'upPcId': 'fca679fe-ecfd-4d7a-824d-86a7b525a747',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 3,
#    'pcSeq': 15615,
#    'pcNm': '내장판 조정작업',
#    'pcCd': 'PROC0004',
#    'desc1': None},
#   {'pcId': '406990fb-253f-4b65-a7db-c7e50f6775cb',
#    'upPcId': 'fca679fe-ecfd-4d7a-824d-86a7b525a747',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 3,
#    'pcSeq': 15616,
#    'pcNm': '객실도어 취부 검사',
#    'pcCd': 'PROC0004',
#    'desc1': None},
#   {'pcId': '67114600-1c26-4313-941b-10c2e4d6a1ff',
#    'upPcId': 'fca679fe-ecfd-4d7a-824d-86a7b525a747',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 3,
#    'pcSeq': 15617,
#    'pcNm': '운전실 배전반 취부 결선',
#    'pcCd': 'PROC0004',
#    'desc1': None},
#   {'pcId': 'd1e83483-4e9b-4b1a-beba-9a8994d06528',
#    'upPcId': 'fca679fe-ecfd-4d7a-824d-86a7b525a747',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 3,
#    'pcSeq': 15617,
#    'pcNm': '내장판 취부 검사',
#    'pcCd': 'PROC0004',
#    'desc1': None},
#   {'pcId': 'c49e416e-39de-48d6-815a-4ee0e734015b',
#    'upPcId': 'fca679fe-ecfd-4d7a-824d-86a7b525a747',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 3,
#    'pcSeq': 15618,
#    'pcNm': '운전실 DOOR 취부',
#    'pcCd': 'PROC0004',
#    'desc1': None},
#   {'pcId': 'b9ef1a5a-4fb4-4003-99a8-ba538e2cebad',
#    'upPcId': 'fca679fe-ecfd-4d7a-824d-86a7b525a747',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 3,
#    'pcSeq': 15619,
#    'pcNm': '핸드레일 취부',
#    'pcCd': 'PROC0004',
#    'desc1': None},
#   {'pcId': '4bf6bfb9-170c-4409-bc1a-86ebce6b2cb3',
#    'upPcId': 'fca679fe-ecfd-4d7a-824d-86a7b525a747',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 3,
#    'pcSeq': 15620,
#    'pcNm': '시트프레임 취부',
#    'pcCd': 'PROC0004',
#    'desc1': None},
#   {'pcId': '0a1ebad7-306b-4f6d-87f1-6adb7bc1d0cd',
#    'upPcId': 'fca679fe-ecfd-4d7a-824d-86a7b525a747',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 3,
#    'pcSeq': 15620,
#    'pcNm': '운전실 전장기기 취부 결선',
#    'pcCd': 'PROC0004',
#    'desc1': None},
#   {'pcId': '334a0ed5-dbfc-4843-aa59-cb6778327135',
#    'upPcId': 'fca679fe-ecfd-4d7a-824d-86a7b525a747',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 3,
#    'pcSeq': 15621,
#    'pcNm': '실내/운전실 설비 완료',
#    'pcCd': 'PROC0004',
#    'desc1': None},
#   {'pcId': 'd36c94ac-5eb3-494d-817a-94bff3ce20ba',
#    'upPcId': 'fca679fe-ecfd-4d7a-824d-86a7b525a747',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 3,
#    'pcSeq': 15622,
#    'pcNm': '도어 조정 및 비상핸들 취부',
#    'pcCd': 'PROC0004',
#    'desc1': None},
#   {'pcId': '91b53f04-d941-4c7c-9e8c-b662c397d24e',
#    'upPcId': 'fca679fe-ecfd-4d7a-824d-86a7b525a747',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 3,
#    'pcSeq': 15622,
#    'pcNm': '실내 전장품 취부 결선',
#    'pcCd': 'PROC0004',
#    'desc1': None},
#   {'pcId': '82f2b54d-7efc-4358-8d8a-55ba0d56cb2e',
#    'upPcId': 'fca679fe-ecfd-4d7a-824d-86a7b525a747',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 3,
#    'pcSeq': 15623,
#    'pcNm': '실외 설비품/DIAPHRAGM 취부',
#    'pcCd': 'PROC0004',
#    'desc1': None},
#   {'pcId': '59043214-e767-4ba2-8992-754b68dfebea',
#    'upPcId': 'fca679fe-ecfd-4d7a-824d-86a7b525a747',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 3,
#    'pcSeq': 15624,
#    'pcNm': '전장기기 취부 결선 완료',
#    'pcCd': 'PROC0004',
#    'desc1': None},
#   {'pcId': 'cda683bc-360a-4640-a32b-92730634f4ed',
#    'upPcId': 'fca679fe-ecfd-4d7a-824d-86a7b525a747',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 3,
#    'pcSeq': 15624,
#    'pcNm': '드라프트 스크린 취부',
#    'pcCd': 'PROC0004',
#    'desc1': None},
#   {'pcId': '855fdc32-39ec-49d9-b88d-0346fbd94201',
#    'upPcId': 'fca679fe-ecfd-4d7a-824d-86a7b525a747',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 3,
#    'pcSeq': 15624,
#    'pcNm': '실외 전장품 취부 결선',
#    'pcCd': 'PROC0004',
#    'desc1': None},
#   {'pcId': '76448a5b-a2ce-4db0-b0bd-3b4763b00c32',
#    'upPcId': 'fca679fe-ecfd-4d7a-824d-86a7b525a747',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 3,
#    'pcSeq': 15625,
#    'pcNm': '스텐션폴 취부',
#    'pcCd': 'PROC0004',
#    'desc1': None},
#   {'pcId': '347041ed-ed49-4175-8391-6dd284b4e637',
#    'upPcId': 'fca679fe-ecfd-4d7a-824d-86a7b525a747',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 3,
#    'pcSeq': 15625,
#    'pcNm': '도통 자체 검사 (TC-Car)',
#    'pcCd': 'PROC0004',
#    'desc1': None},
#   {'pcId': '5c6a0ac9-1c16-4d10-897b-0dd4ffb7e4fd',
#    'upPcId': 'fca679fe-ecfd-4d7a-824d-86a7b525a747',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 3,
#    'pcSeq': 15626,
#    'pcNm': '핸드스트랩 취부',
#    'pcCd': 'PROC0004',
#    'desc1': None},
#   {'pcId': 'f12e681f-1f2a-46b1-819c-c22d580a0a3b',
#    'upPcId': 'fca679fe-ecfd-4d7a-824d-86a7b525a747',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 3,
#    'pcSeq': 15626,
#    'pcNm': 'D+17~20일차 조정작업',
#    'pcCd': 'PROC0004',
#    'desc1': None},
#   {'pcId': '7a21a47f-fea2-4c33-a991-c9fbe85eec90',
#    'upPcId': 'fca679fe-ecfd-4d7a-824d-86a7b525a747',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 3,
#    'pcSeq': 15626,
#    'pcNm': '도통 검사 수정 (TC-Car)',
#    'pcCd': 'PROC0004',
#    'desc1': None},
#   {'pcId': '09434017-3571-48a5-a58e-1ebc0fe1f60c',
#    'upPcId': 'fca679fe-ecfd-4d7a-824d-86a7b525a747',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 3,
#    'pcSeq': 15627,
#    'pcNm': '선반 취부',
#    'pcCd': 'PROC0004',
#    'desc1': None},
#   {'pcId': 'ef4ef3c1-5598-4f99-bd0d-b45bf186a3aa',
#    'upPcId': 'fca679fe-ecfd-4d7a-824d-86a7b525a747',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 3,
#    'pcSeq': 15627,
#    'pcNm': '내전압 입회 검사 (TC-Car)',
#    'pcCd': 'PROC0004',
#    'desc1': None},
#   {'pcId': 'e9ec7ceb-5417-45a3-97b1-4a74d1524d06',
#    'upPcId': 'fca679fe-ecfd-4d7a-824d-86a7b525a747',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 3,
#    'pcSeq': 15628,
#    'pcNm': '형광등 취부',
#    'pcCd': 'PROC0004',
#    'desc1': None},
#   {'pcId': '9cda7382-f0bd-4b0a-908d-82d5c83fb0c4',
#    'upPcId': 'fca679fe-ecfd-4d7a-824d-86a7b525a747',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 3,
#    'pcSeq': 15629,
#    'pcNm': '도통 검사 (TC-Car)',
#    'pcCd': 'PROC0004',
#    'desc1': None},
#   {'pcId': 'ab8e3300-77e8-45dc-9686-49f2bcac6328',
#    'upPcId': 'fca679fe-ecfd-4d7a-824d-86a7b525a747',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 3,
#    'pcSeq': 15629,
#    'pcNm': '장애인 설비, 기타 설비 취부',
#    'pcCd': 'PROC0004',
#    'desc1': None},
#   {'pcId': '07cda3b6-bee6-4b16-a2fa-3a6b02a50689',
#    'upPcId': 'fca679fe-ecfd-4d7a-824d-86a7b525a747',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 3,
#    'pcSeq': 15630,
#    'pcNm': '전장취부 결선 복구',
#    'pcCd': 'PROC0004',
#    'desc1': None},
#   {'pcId': '9a6519e5-8bd2-443e-8bd0-e3787716fe7d',
#    'upPcId': 'fca679fe-ecfd-4d7a-824d-86a7b525a747',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 3,
#    'pcSeq': 15631,
#    'pcNm': '실내 조정 및 실내·외 설비 완료',
#    'pcCd': 'PROC0004',
#    'desc1': None},
#   {'pcId': 'b6cd7eb1-2faa-4127-a457-8744facf75d7',
#    'upPcId': 'fca679fe-ecfd-4d7a-824d-86a7b525a747',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 3,
#    'pcSeq': 15632,
#    'pcNm': '전장품 취부 입회검사',
#    'pcCd': 'PROC0004',
#    'desc1': None},
#   {'pcId': '793cf042-2a6d-409b-a7a6-38cca3701aa0',
#    'upPcId': 'fca679fe-ecfd-4d7a-824d-86a7b525a747',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 3,
#    'pcSeq': 15633,
#    'pcNm': '수정작업 및 점검커버 복구 (전기)',
#    'pcCd': 'PROC0004',
#    'desc1': None},
#   {'pcId': '1e3ab08b-af38-4c6a-9873-9fbf37f51e6c',
#    'upPcId': 'fca679fe-ecfd-4d7a-824d-86a7b525a747',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 3,
#    'pcSeq': 15634,
#    'pcNm': '수정작업 및 점검커버 복구 (의장)',
#    'pcCd': 'PROC0004',
#    'desc1': None},
#   {'pcId': 'f8c98cd0-4d74-4cea-8a88-8b9adb2fd07e',
#    'upPcId': 'fca679fe-ecfd-4d7a-824d-86a7b525a747',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 3,
#    'pcSeq': 15635,
#    'pcNm': '실내 설비 입회검사',
#    'pcCd': 'PROC0004',
#    'desc1': None},
#   {'pcId': '118546fb-155d-4fd4-b716-334ac5602428',
#    'upPcId': '64af7702-2d7a-44c1-8325-ca25acc93516',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 3,
#    'pcSeq': 20101,
#    'pcNm': '대차차입 전 검사 / 대차 차입',
#    'pcCd': 'PROC0005',
#    'desc1': None},
#   {'pcId': '8a67c4be-49c7-4cb5-a5e0-8ac51ec40122',
#    'upPcId': '64af7702-2d7a-44c1-8325-ca25acc93516',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 3,
#    'pcSeq': 20102,
#    'pcNm': '대차 결선',
#    'pcCd': 'PROC0005',
#    'desc1': None},
#   {'pcId': '052160b2-51dc-42ef-aa56-bc7c4f472bfa',
#    'upPcId': '64af7702-2d7a-44c1-8325-ca25acc93516',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 3,
#    'pcSeq': 20103,
#    'pcNm': '접지선 결선',
#    'pcCd': 'PROC0005',
#    'desc1': None},
#   {'pcId': '2a2f3901-14cb-45b4-b17a-d12a569790ea',
#    'upPcId': '64af7702-2d7a-44c1-8325-ca25acc93516',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 3,
#    'pcSeq': 20201,
#    'pcNm': '대차측 전장품 취부 결선 & 마무리작업',
#    'pcCd': 'PROC0005',
#    'desc1': None},
#   {'pcId': 'cfae0823-3d36-4f38-a902-619beca12b22',
#    'upPcId': '64af7702-2d7a-44c1-8325-ca25acc93516',
#    'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#    'pcLevel': 3,
#    'pcSeq': 20301,
#    'pcNm': '대차차입 후 검사',
#    'pcCd': 'PROC0005',
#    'desc1': None}]}

# %%
len(data_process_category['data'])
# Out:
# 207

# %%
data_process_category['data'][0]
# Out:
# {'pcId': 'ee9d0398-8fae-48e4-b1a8-dbdc4029b4da',
#  'upPcId': None,
#  'siteId': '447477ef-0986-4d2a-80f5-69d445b8a803',
#  'pcLevel': 1,
#  'pcSeq': 1,
#  'pcNm': '차체',
#  'pcCd': 'PROC0001',
#  'desc1': '차체 대분류'}

# %%
name = [data_process_category['data'][i]['pcNm'] for i in range(len(data_process_category['data']))]

# %%
name
# Out:
# ['차체',
#  '차체 운송',
#  '도장',
#  '도장 운송',
#  '선행의장',
#  '선행의장 운송',
#  '의장/전장/기장',
#  '본의장 운송',
#  '대차 차입',
#  '대차 운송',
#  'UNDER PANEL 조립 & 검사 & 자동용접',
#  '운송 차제2->차체3',
#  'UNDER PANEL 교정',
#  '운송 차제3->차체4',
#  'UNDER PANEL 가공',
#  '운송 차제4->차체5',
#  'UNDER PANEL 세척/사상/검사',
#  '운송 차제5->차체6',
#  'UNDER SIDE SILL 조립 & 자동용접',
#  '운송 차제6->차체7',
#  'UNDER SIDE SILL 교정',
#  '운송 차제7->차체8',
#  'UNDER PANEL 팽창폼 삽입',
#  '운송 차제8->차체9',
#  'UNDER FRAME ASSY END SILL 용접',
#  '운송 차제9->차체10',
#  'UNDER FRAME ASSY 2차 조립 & 용접 & 검사',
#  '운송 차제10->차체11',
#  'UNDER FRAME 2차 가공',
#  '운송 차제11->차체12',
#  'UNDER FRAME 가공 세척/사상 & 용접',
#  '운송 차제12->차체13',
#  'UNDER FRAME ASSY 검사',
#  '운송 차제13->차체14',
#  'UNDER/END/SIDE/ROOF 조립',
#  '운송 차제14->차체15',
#  'CARBODY 자동 & 수동용접',
#  '운송 차제15->차체16',
#  'CARBODY ASSY 용접 & 교정 & 사상 & 검사',
#  '운송 차제16->차체17',
#  'CARBODY ASSY 교정 & 수정 & 완성검사',
#  '운송 차체->도장',
#  'SHOT 작업',
#  'SHOT작업 및 전처리검사',
#  '전처리검사',
#  '운송 도장2->도장3',
#  '하도 및 건조',
#  '운송 도장3->도장4',
#  '용접수정 및 검사',
#  '운송 도장4->도장5',
#  '하도수정 및 검사',
#  '운송 도장5->도장6',
#  '퍼티 1차',
#  '퍼티 및 퍼티 검사',
#  '퍼티 2차',
#  '퍼티 3차',
#  '퍼티 4차',
#  '퍼티 연마',
#  '퍼티검사',
#  '운송 도장6->도장7',
#  '중도 (중도 + 중도 touch up)',
#  '중도 및 중도검사',
#  '중도검사',
#  '운송 도장7->도장8',
#  '상도',
#  '상도 및 상도검사',
#  '상도검사',
#  '운송 도장8->도장9',
#  '안티슬립 하도 방음도장',
#  '안티슬립 및 상도/방음검사',
#  '지붕도막재 하도 검사',
#  '안티슬립 중도 방음도장',
#  '지붕도막재 중도 검사',
#  '안티슬립 규사, 상도 방음도장',
#  '전체가수 및 씰링',
#  '지붕도막재 규사, 상도/방음 도장 검사',
#  '운송 도장->선행의장',
#  '선행 의장',
#  '평활재시공 & 단열재 취부',
#  '단열재 취부 검사',
#  '평활재 연마',
#  '평활재 시공상태 검사',
#  '바닥재 시공',
#  '바닥재 시공상태 검사',
#  '운송 선행의장 -> 의장',
#  '의장/전장/기장',
#  '보호합판 시공',
#  '흡음재 취부 검사',
#  '실내배선',
#  '리무벌 프레임 취부',
#  '측창취부',
#  '실내 입선 검사',
#  'AIR DUCT MODULE 취부',
#  '덕트류 취부검사',
#  'AIR DUCT MODULE 취부 & 상하 CABLE HARNESS 배선',
#  '상하 입선검사',
#  '객실도어 & 배전반 & 상하 전선관',
#  '제동배관 취부검사',
#  '객실 도어 & 측정 & 배관 & 공기관 취부 & 누기시험',
#  '제동기기 취부 및 누설검사',
#  '내장판 & 배전반 & DOOR & 전선관 배관',
#  '냉방장치 & 공기관 배관',
#  '내장판 & 옥상 & 형광등',
#  'cover & 형광등 & 전광판& LJB 취부 및 결선',
#  'SIDE DOOR & HINGE &FAN & 등구류 & 제동기기결선 및 취부',
#  'DOOR/END & 전장품 &옥상 전장기기 취부',
#  '내장판 취부 검사',
#  '소형기기 취부 결선',
#  '상하 전장기기 결선',
#  '선반 & 전장 & 상하부품 취부',
#  'TRACTION MOTOR 결선 (1차)& COUPLER 취부',
#  '점검카바 취부',
#  'TRACTION MOTOR 결선 (2차)',
#  '실내명판 & 옥상기기 취부',
#  '하부 M/D & 실외 전장품 취부 및 결선',
#  '실외설비품 & 소화기 취부',
#  '실내설비/전장품 취부검사',
#  '운송 본의장 -> 완성 의장',
#  '대차 차입 및 배관 마무리작업',
#  '운송 의장 -> 완료검사',
#  '파이프 프레임, 탭시트',
#  '방풍라바,와이어스포트',
#  '이너프레임',
#  '단열재 취부',
#  '단열재 검사',
#  '평활재 건조',
#  '평활재 검사',
#  '바닥재 건조',
#  '바닥재 검사',
#  '흡음재 취부',
#  '흡음재 씰링/검사/수정',
#  'T-BOLT 취부',
#  '배기팬 커버 취부',
#  '전장품 취부 및 고압 배선 압착작업',
#  '내전압 검사 (상,하 전기)',
#  '실내 배선',
#  '실내 입선 검사',
#  '일반 배전반 취부',
#  '냉난방 배전반 배선 및 컨넥트 작업',
#  '운전실 1차 배선 작업',
#  '운전실 2차 배선작업 및 기기류 컨넥트 작업',
#  '실내/상하 CABLE HARNESS 취부',
#  '실내/상하 배선',
#  'D+1~4일차 조정작업',
#  '실내/상하 입선 검사/수정',
#  '리무벌프레임 취부',
#  'AIR DUCT MODULE 취부',
#  '측창취부',
#  'STOP PLATE & 센터그릴 취부',
#  '파티션 프레임 취부',
#  'LINE FLOW FAN 취부 결선',
#  'AIR DUCT MODULE 취부 검사',
#  'CAB MODULE 취부',
#  'AIR CON 취부',
#  'ROOF 내장판 취부',
#  '운전실 내장판/캐비넷 취부',
#  '배관 MODULE 취부',
#  '객실 도어 취부',
#  '일반,냉난방 배전반 취부 결선',
#  '옥상기기 취부 결선',
#  '상하 전장기기 취부 결선',
#  'CENTER PIVOT 취부',
#  '도통 검사',
#  '부적합수정',
#  'COUPLER 취부',
#  '도통입회검사/내전압자체검사',
#  '제동기기 취부 및 누설검사',
#  'SIDE 내장판 취부',
#  '내전압 입회검사',
#  '코너씰링',
#  'D+5~16일차 조정작업',
#  '내장판 조정작업',
#  '객실도어 취부 검사',
#  '운전실 배전반 취부 결선',
#  '내장판 취부 검사',
#  '운전실 DOOR 취부',
#  '핸드레일 취부',
#  '시트프레임 취부',
#  '운전실 전장기기 취부 결선',
#  '실내/운전실 설비 완료',
#  '도어 조정 및 비상핸들 취부',
#  '실내 전장품 취부 결선',
#  '실외 설비품/DIAPHRAGM 취부',
#  '전장기기 취부 결선 완료',
#  '드라프트 스크린 취부',
#  '실외 전장품 취부 결선',
#  '스텐션폴 취부',
#  '도통 자체 검사 (TC-Car)',
#  '핸드스트랩 취부',
#  'D+17~20일차 조정작업',
#  '도통 검사 수정 (TC-Car)',
#  '선반 취부',
#  '내전압 입회 검사 (TC-Car)',
#  '형광등 취부',
#  '도통 검사 (TC-Car)',
#  '장애인 설비, 기타 설비 취부',
#  '전장취부 결선 복구',
#  '실내 조정 및 실내·외 설비 완료',
#  '전장품 취부 입회검사',
#  '수정작업 및 점검커버 복구 (전기)',
#  '수정작업 및 점검커버 복구 (의장)',
#  '실내 설비 입회검사',
#  '대차차입 전 검사 / 대차 차입',
#  '대차 결선',
#  '접지선 결선',
#  '대차측 전장품 취부 결선 & 마무리작업',
#  '대차차입 후 검사']

# %%
'대차차입 후 검사' in name
# Out:
# True

# %%
df_name = pd.read_excel('../data/생관3-612-24-007_2024년 4월 일일생산계획 및 업체별 차종현황_Rev.00_24.03.28(확정).xlsx',
                        skiprows=[0, 1, 2], usecols='C', nrows=64)
df_data = pd.read_excel('../data/생관3-612-24-007_2024년 4월 일일생산계획 및 업체별 차종현황_Rev.00_24.03.28(확정).xlsx',
                        skiprows=[0, 1, 2, 3], usecols='F:BE', nrows=64)

df_name = df_name.drop(index=df_name.index[0])
df_name = df_name.reset_index(drop=True)
df_name = df_name.map(lambda x: x.strip() if isinstance(x, str) else x)
df_name = df_name.ffill()
df_data = df_data.drop(index=df_data.index[-1])
df_data = df_data.drop(index=df_data.index[-1])
df_data.index = df_name['세부공정명'].tolist()

# %%
index = list(df_data.index)

# %%
index
# Out:
# ['흡음재 취부',
#  '흡음재 씰링/검사/수정',
#  '측창취부/T-BOLT 삽입',
#  '실내/상하 CABLE HARNESS 취부',
#  '실내/상하 배선',
#  '실내 배선 작업',
#  '객실도어 취부',
#  '리무벌/파티션 프레임 취부',
#  '객실도어 취부 검사',
#  '하부덕트검사\n (D+1~4일차 조정작업)',
#  '실내 배선 검사',
#  'AIR DUCT MODULE 취부',
#  'CENTER GRILL 취부',
#  'AIR DUCT MODULE 취부 검사',
#  'CAB MODULE 취부(TC)',
#  '배관 MODULE 취부',
#  '배전반 취부 및 배선작업',
#  'CENTER PIVOT 취부',
#  'COUPLER 취부',
#  '제동기기 취부 및 누설검사',
#  '운전실 내장판 취부',
#  'D+5~13일차 조정작업',
#  'ROOF 내장판 취부',
#  '운전실 캐비넷 취부(TC)',
#  '상하 전장기기 취부 결선',
#  'SIDE 내장판 취부',
#  '운전실 배전반 결선(TC)',
#  'AIR CON 취부',
#  '내장판 조정작업(완료)',
#  '내장판 취부 검사',
#  '운전실 DOOR 취부(TC)',
#  '전장기기 취부 결선 완료',
#  '운전실 전장기기 취부 결선(TC)',
#  '도통검사(량단위 시험기)',
#  '도통검사(량단위 시험기)',
#  '도통 자체 검사(완료)',
#  '도통 자체 검사(완료)',
#  '도통 검사 수정',
#  '도통 검사 수정',
#  '도통입회검사/내전압자체검사',
#  '도통입회검사/내전압자체검사',
#  '내전압 입회검사',
#  '내전압 입회검사',
#  '수정작업 및 점검커버 복구',
#  '수정작업 및 점검커버 복구',
#  'D+17~20일차 조정작업',
#  'D+17~20일차 조정작업',
#  '전장취부, 결선 복구 완료',
#  '전장취부, 결선 복구 완료',
#  '실내 조정 및 실내·외 설비 완료',
#  '실내 조정 및 실내·외 설비 완료',
#  '전장품 취부 입회검사',
#  '전장품 취부 입회검사',
#  '복구 및 수정작업',
#  '복구 및 수정작업',
#  '실내 설비 입회검사',
#  '실내 설비 입회검사',
#  '대차차입 전검사 / 대차차입',
#  '대차차입 전검사 / 대차차입',
#  '대차 전장품 취부 결선 & 마무리',
#  '대차 전장품 취부 결선 & 마무리',
#  '대차차입 후 검사']

# %%
for i in index:
    print(i in name)
# Out:
# True
# True
# False
# True
# True
# False
# False
# False
# True
# False
# False
# True
# False
# True
# False
# True
# False
# True
# True
# True
# False
# False
# True
# False
# True
# True
# False
# True
# False
# True
# False
# True
# False
# False
# False
# False
# False
# False
# False
# True
# True
# True
# True
# False
# False
# True
# True
# False
# False
# True
# True
# True
# True
# False
# False
# True
# True
# False
# False
# False
# False
# True

# %%
url490 = 'https://corners.synology.me:30006/woojin-dev490/Processes/Seq/49e69005-31f0-4554-becd-7a296b7bdad2'
url336 = 'https://corners.synology.me:30006/woojin-dev490/Processes/Seq/e672bd1e-5ed0-4baa-9cbd-50db20ea24db'


data490 = load_api(url490)
data336 = load_api(url336)

# %%
name490 = [data490['data'][i]['pcNm'] for i in range(len(data490['data']))]
name490
# Out:
# ['UNDER PANEL 조립 & 검사 & 자동용접',
#  '운송 차제2->차체3',
#  'UNDER PANEL 교정',
#  '운송 차제3->차체4',
#  'UNDER PANEL 가공',
#  '운송 차제4->차체5',
#  'UNDER PANEL 세척/사상/검사',
#  '운송 차제5->차체6',
#  'UNDER SIDE SILL 조립 & 자동용접',
#  '운송 차제6->차체7',
#  'UNDER SIDE SILL 교정',
#  '운송 차제7->차체8',
#  'UNDER PANEL 팽창폼 삽입',
#  '운송 차제8->차체9',
#  'UNDER FRAME ASSY END SILL 용접',
#  '운송 차제9->차체10',
#  'UNDER FRAME ASSY 2차 조립 & 용접 & 검사',
#  '운송 차제10->차체11',
#  'UNDER FRAME 2차 가공',
#  '운송 차제11->차체12',
#  'UNDER FRAME 가공 세척/사상 & 용접',
#  '운송 차제12->차체13',
#  'UNDER FRAME ASSY 검사',
#  '운송 차제13->차체14',
#  'UNDER/END/SIDE/ROOF 조립',
#  '운송 차제14->차체15',
#  'CARBODY 자동 & 수동용접',
#  '운송 차제15->차체16',
#  'CARBODY ASSY 용접 & 교정 & 사상 & 검사',
#  '운송 차제16->차체17',
#  'CARBODY ASSY 교정 & 수정 & 완성검사',
#  '운송 차체->도장',
#  'SHOT작업 및 전처리검사',
#  '운송 도장2->도장3',
#  '하도 및 건조',
#  '운송 도장3->도장4',
#  '용접수정 및 검사',
#  '운송 도장4->도장5',
#  '하도수정 및 검사',
#  '운송 도장5->도장6',
#  '퍼티 및 퍼티 검사',
#  '운송 도장6->도장7',
#  '중도 및 중도검사',
#  '운송 도장7->도장8',
#  '상도 및 상도검사',
#  '운송 도장8->도장9',
#  '안티슬립 및 상도/방음검사',
#  '운송 도장->선행의장',
#  '선행 의장',
#  '운송 선행의장 -> 의장',
#  '의장/전장/기장',
#  '운송 본의장 -> 완성 의장',
#  '대차 차입 및 배관 마무리작업',
#  '운송 의장 -> 완료검사']

# %%
name336 = [data336['data'][i]['pcNm'] for i in range(len(data336['data']))]
name336
# Out:
# ['UNDER PANEL 조립 & 검사 & 자동용접',
#  '운송 차제2->차체3',
#  'UNDER PANEL 교정',
#  '운송 차제3->차체4',
#  'UNDER PANEL 가공',
#  '운송 차제4->차체5',
#  'UNDER PANEL 세척/사상/검사',
#  '운송 차제5->차체6',
#  'UNDER SIDE SILL 조립 & 자동용접',
#  '운송 차제6->차체7',
#  'UNDER SIDE SILL 교정',
#  '운송 차제7->차체8',
#  'UNDER PANEL 팽창폼 삽입',
#  '운송 차제8->차체9',
#  'UNDER FRAME ASSY END SILL 용접',
#  '운송 차제9->차체10',
#  'UNDER FRAME ASSY 2차 조립 & 용접 & 검사',
#  '운송 차제10->차체11',
#  'UNDER FRAME 2차 가공',
#  '운송 차제11->차체12',
#  'UNDER FRAME 가공 세척/사상 & 용접',
#  '운송 차제12->차체13',
#  'UNDER FRAME ASSY 검사',
#  '운송 차제13->차체14',
#  'UNDER/END/SIDE/ROOF 조립',
#  '운송 차제14->차체15',
#  'CARBODY 자동 & 수동용접',
#  '운송 차제15->차체16',
#  'CARBODY ASSY 용접 & 교정 & 사상 & 검사',
#  '운송 차제16->차체17',
#  'CARBODY ASSY 교정 & 수정 & 완성검사',
#  '운송 차체->도장',
#  'SHOT 작업',
#  'SHOT작업 및 전처리검사',
#  '전처리검사',
#  '운송 도장2->도장3',
#  '하도 및 건조',
#  '운송 도장3->도장4',
#  '용접수정 및 검사',
#  '운송 도장4->도장5',
#  '하도수정 및 검사',
#  '운송 도장5->도장6',
#  '퍼티 1차',
#  '퍼티 및 퍼티 검사',
#  '퍼티 2차',
#  '퍼티 3차',
#  '퍼티 4차',
#  '퍼티 연마',
#  '퍼티검사',
#  '운송 도장6->도장7',
#  '중도 (중도 + 중도 touch up)',
#  '중도 및 중도검사',
#  '중도검사',
#  '운송 도장7->도장8',
#  '상도',
#  '상도 및 상도검사',
#  '상도검사',
#  '운송 도장8->도장9',
#  '안티슬립 하도 방음도장',
#  '안티슬립 및 상도/방음검사',
#  '지붕도막재 하도 검사',
#  '안티슬립 중도 방음도장',
#  '지붕도막재 중도 검사',
#  '안티슬립 규사, 상도 방음도장',
#  '전체가수 및 씰링',
#  '지붕도막재 규사, 상도/방음 도장 검사',
#  '운송 도장->선행의장',
#  '선행 의장',
#  '평활재시공 & 단열재 취부',
#  '단열재 취부 검사',
#  '평활재 연마',
#  '평활재 시공상태 검사',
#  '바닥재 시공',
#  '바닥재 시공상태 검사',
#  '운송 선행의장 -> 의장',
#  '의장/전장/기장',
#  '보호합판 시공',
#  '흡음재 취부 검사',
#  '실내배선',
#  '리무벌 프레임 취부',
#  '측창취부',
#  '실내 입선 검사',
#  'AIR DUCT MODULE 취부',
#  '덕트류 취부검사',
#  'AIR DUCT MODULE 취부 & 상하 CABLE HARNESS 배선',
#  '상하 입선검사',
#  '객실도어 & 배전반 & 상하 전선관',
#  '제동배관 취부검사',
#  '객실 도어 & 측정 & 배관 & 공기관 취부 & 누기시험',
#  '제동기기 취부 및 누설검사',
#  '내장판 & 배전반 & DOOR & 전선관 배관',
#  '냉방장치 & 공기관 배관',
#  '내장판 & 옥상 & 형광등',
#  'cover & 형광등 & 전광판& LJB 취부 및 결선',
#  'SIDE DOOR & HINGE &FAN & 등구류 & 제동기기결선 및 취부',
#  'DOOR/END & 전장품 &옥상 전장기기 취부',
#  '내장판 취부 검사',
#  '소형기기 취부 결선',
#  '상하 전장기기 결선',
#  '선반 & 전장 & 상하부품 취부',
#  'TRACTION MOTOR 결선 (1차)& COUPLER 취부',
#  '점검카바 취부',
#  'TRACTION MOTOR 결선 (2차)',
#  '실내명판 & 옥상기기 취부',
#  '하부 M/D & 실외 전장품 취부 및 결선',
#  '실외설비품 & 소화기 취부',
#  '실내설비/전장품 취부검사',
#  '운송 본의장 -> 완성 의장',
#  '대차 차입 및 배관 마무리작업',
#  '운송 의장 -> 완료검사']

# %%
c = 0
for n in name336:
    if '검사' in n:
        print(n)
        c+=1
print(c)
# Out:
# UNDER PANEL 조립 & 검사 & 자동용접
# UNDER PANEL 세척/사상/검사
# UNDER FRAME ASSY 2차 조립 & 용접 & 검사
# UNDER FRAME ASSY 검사
# CARBODY ASSY 용접 & 교정 & 사상 & 검사
# CARBODY ASSY 교정 & 수정 & 완성검사
# SHOT작업 및 전처리검사
# 전처리검사
# 용접수정 및 검사
# 하도수정 및 검사
# 퍼티 및 퍼티 검사
# 퍼티검사
# 중도 및 중도검사
# 중도검사
# 상도 및 상도검사
# 상도검사
# 안티슬립 및 상도/방음검사
# 지붕도막재 하도 검사
# 지붕도막재 중도 검사
# 지붕도막재 규사, 상도/방음 도장 검사
# 단열재 취부 검사
# 평활재 시공상태 검사
# 바닥재 시공상태 검사
# 흡음재 취부 검사
# 실내 입선 검사
# 덕트류 취부검사
# 상하 입선검사
# 제동배관 취부검사
# 제동기기 취부 및 누설검사
# 내장판 취부 검사
# 실내설비/전장품 취부검사
# 운송 의장 -> 완료검사
# 32

# %%
c = 0
for n in name490:
    if '검사' in n:
        print(n)
        c+=1
print(c)
# Out:
# UNDER PANEL 조립 & 검사 & 자동용접
# UNDER PANEL 세척/사상/검사
# UNDER FRAME ASSY 2차 조립 & 용접 & 검사
# UNDER FRAME ASSY 검사
# CARBODY ASSY 용접 & 교정 & 사상 & 검사
# CARBODY ASSY 교정 & 수정 & 완성검사
# SHOT작업 및 전처리검사
# 용접수정 및 검사
# 하도수정 및 검사
# 퍼티 및 퍼티 검사
# 중도 및 중도검사
# 상도 및 상도검사
# 안티슬립 및 상도/방음검사
# 운송 의장 -> 완료검사
# 14

# %%
len(set(name336 + name490))
# Out:
# 110

# %%
len(name336), len(name490)
# Out:
# (110, 54)

# %%
for i in name336:
    if i not in name:
        print(i)

# %%
for i in name490:
    if i not in name:
        print(i)

# %%
for i in index:
    if i not in name:
        print(i)
# Out:
# 측창취부/T-BOLT 삽입
# 실내 배선 작업
# 객실도어 취부
# 리무벌/파티션 프레임 취부
# 하부덕트검사
#  (D+1~4일차 조정작업)
# 실내 배선 검사
# CENTER GRILL 취부
# CAB MODULE 취부(TC)
# 배전반 취부 및 배선작업
# 운전실 내장판 취부
# D+5~13일차 조정작업
# 운전실 캐비넷 취부(TC)
# 운전실 배전반 결선(TC)
# 내장판 조정작업(완료)
# 운전실 DOOR 취부(TC)
# 운전실 전장기기 취부 결선(TC)
# 도통검사(량단위 시험기)
# 도통검사(량단위 시험기)
# 도통 자체 검사(완료)
# 도통 자체 검사(완료)
# 도통 검사 수정
# 도통 검사 수정
# 수정작업 및 점검커버 복구
# 수정작업 및 점검커버 복구
# 전장취부, 결선 복구 완료
# 전장취부, 결선 복구 완료
# 복구 및 수정작업
# 복구 및 수정작업
# 대차차입 전검사 / 대차차입
# 대차차입 전검사 / 대차차입
# 대차 전장품 취부 결선 & 마무리
# 대차 전장품 취부 결선 & 마무리

# %%
for i in index:
    if i not in name336:
        print(i)
# Out:
# 흡음재 취부
# 흡음재 씰링/검사/수정
# 측창취부/T-BOLT 삽입
# 실내/상하 CABLE HARNESS 취부
# 실내/상하 배선
# 실내 배선 작업
# 객실도어 취부
# 리무벌/파티션 프레임 취부
# 객실도어 취부 검사
# 하부덕트검사
#  (D+1~4일차 조정작업)
# 실내 배선 검사
# CENTER GRILL 취부
# AIR DUCT MODULE 취부 검사
# CAB MODULE 취부(TC)
# 배관 MODULE 취부
# 배전반 취부 및 배선작업
# CENTER PIVOT 취부
# COUPLER 취부
# 운전실 내장판 취부
# D+5~13일차 조정작업
# ROOF 내장판 취부
# 운전실 캐비넷 취부(TC)
# 상하 전장기기 취부 결선
# SIDE 내장판 취부
# 운전실 배전반 결선(TC)
# AIR CON 취부
# 내장판 조정작업(완료)
# 운전실 DOOR 취부(TC)
# 전장기기 취부 결선 완료
# 운전실 전장기기 취부 결선(TC)
# 도통검사(량단위 시험기)
# 도통검사(량단위 시험기)
# 도통 자체 검사(완료)
# 도통 자체 검사(완료)
# 도통 검사 수정
# 도통 검사 수정
# 도통입회검사/내전압자체검사
# 도통입회검사/내전압자체검사
# 내전압 입회검사
# 내전압 입회검사
# 수정작업 및 점검커버 복구
# 수정작업 및 점검커버 복구
# D+17~20일차 조정작업
# D+17~20일차 조정작업
# 전장취부, 결선 복구 완료
# 전장취부, 결선 복구 완료
# 실내 조정 및 실내·외 설비 완료
# 실내 조정 및 실내·외 설비 완료
# 전장품 취부 입회검사
# 전장품 취부 입회검사
# 복구 및 수정작업
# 복구 및 수정작업
# 실내 설비 입회검사
# 실내 설비 입회검사
# 대차차입 전검사 / 대차차입
# 대차차입 전검사 / 대차차입
# 대차 전장품 취부 결선 & 마무리
# 대차 전장품 취부 결선 & 마무리
# 대차차입 후 검사

# %%
for i in index:
    if i not in name490:
        print(i)
# Out:
# 흡음재 취부
# 흡음재 씰링/검사/수정
# 측창취부/T-BOLT 삽입
# 실내/상하 CABLE HARNESS 취부
# 실내/상하 배선
# 실내 배선 작업
# 객실도어 취부
# 리무벌/파티션 프레임 취부
# 객실도어 취부 검사
# 하부덕트검사
#  (D+1~4일차 조정작업)
# 실내 배선 검사
# AIR DUCT MODULE 취부
# CENTER GRILL 취부
# AIR DUCT MODULE 취부 검사
# CAB MODULE 취부(TC)
# 배관 MODULE 취부
# 배전반 취부 및 배선작업
# CENTER PIVOT 취부
# COUPLER 취부
# 제동기기 취부 및 누설검사
# 운전실 내장판 취부
# D+5~13일차 조정작업
# ROOF 내장판 취부
# 운전실 캐비넷 취부(TC)
# 상하 전장기기 취부 결선
# SIDE 내장판 취부
# 운전실 배전반 결선(TC)
# AIR CON 취부
# 내장판 조정작업(완료)
# 내장판 취부 검사
# 운전실 DOOR 취부(TC)
# 전장기기 취부 결선 완료
# 운전실 전장기기 취부 결선(TC)
# 도통검사(량단위 시험기)
# 도통검사(량단위 시험기)
# 도통 자체 검사(완료)
# 도통 자체 검사(완료)
# 도통 검사 수정
# 도통 검사 수정
# 도통입회검사/내전압자체검사
# 도통입회검사/내전압자체검사
# 내전압 입회검사
# 내전압 입회검사
# 수정작업 및 점검커버 복구
# 수정작업 및 점검커버 복구
# D+17~20일차 조정작업
# D+17~20일차 조정작업
# 전장취부, 결선 복구 완료
# 전장취부, 결선 복구 완료
# 실내 조정 및 실내·외 설비 완료
# 실내 조정 및 실내·외 설비 완료
# 전장품 취부 입회검사
# 전장품 취부 입회검사
# 복구 및 수정작업
# 복구 및 수정작업
# 실내 설비 입회검사
# 실내 설비 입회검사
# 대차차입 전검사 / 대차차입
# 대차차입 전검사 / 대차차입
# 대차 전장품 취부 결선 & 마무리
# 대차 전장품 취부 결선 & 마무리
# 대차차입 후 검사
